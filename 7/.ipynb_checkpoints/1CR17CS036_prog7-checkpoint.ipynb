# %% [markdown]
# # Dheeraj J C - 1CR17CS036 (Prog 7)
#
# Write a program to construct a Bayesian network considering medical data. Use this model to demonstrate the diagnosis of heart patients using standard Heart Disease Data Set. You can use Java/Python ML library classes/API.

# %%
from pgmpy.models import BayesianModel

# %%
cancer_model = BayesianModel([("Pollution", "Cancer"),("Smoker", "Cancer"),("Cancer", "Xray"),("Cancer", "Dyspnoea")])

print(cancer_model)

# %%
cancer_model.nodes()
# Out:
# NodeView(('Pollution', 'Cancer', 'Smoker', 'Xray', 'Dyspnoea'))

# %%
cancer_model.edges()
# Out:
# OutEdgeView([('Pollution', 'Cancer'), ('Cancer', 'Xray'), ('Cancer', 'Dyspnoea'), ('Smoker', 'Cancer')])

# %%
cancer_model.get_cpds()
# Out:
# []

# %%
from pgmpy.factors.discrete import TabularCPD

# %%
cpd_poll = TabularCPD(variable="Pollution",variable_card=2,values=[[0.9],[0.1]])
cpd_smoke = TabularCPD(variable="Smoker",variable_card=2,values=[[0.3],[0.7]])
cpd_cancer = TabularCPD(variable="Cancer",variable_card=2,values=[[0.03, 0.05, 0.001, 0.02],[0.97, 0.95, 0.999, 0.98]],evidence=["Smoker", "Pollution"],evidence_card=[2, 2])
cpd_xray = TabularCPD(variable="Xray",variable_card=2,values=[[0.9, 0.2],[0.1, 0.8]],evidence=["Cancer"],evidence_card=[2])
cpd_dysp = TabularCPD(variable="Dyspnoea",variable_card=2,values=[[0.65, 0.3],[0.35, 0.7]],evidence=["Cancer"],evidence_card=[2])
cancer_model.add_cpds(cpd_poll, cpd_smoke, cpd_cancer, cpd_xray, cpd_dysp)
cancer_model.check_model()
# Out:
# True

# %%
cancer_model.is_active_trail("Pollution", "Smoker")
# Out:
# False

# %%
cancer_model.is_active_trail("Pollution", "Smoker", observed=["Cancer"])
# Out:
# True

# %%
cancer_model.get_cpds()
# Out:
# [<TabularCPD representing P(Pollution:2) at 0x2c876230490>,
#  <TabularCPD representing P(Smoker:2) at 0x2c876230430>,
#  <TabularCPD representing P(Cancer:2 | Smoker:2, Pollution:2) at 0x2c8762304f0>,
#  <TabularCPD representing P(Xray:2 | Cancer:2) at 0x2c876230460>,
#  <TabularCPD representing P(Dyspnoea:2 | Cancer:2) at 0x2c8762304c0>]

# %%
print(cancer_model.get_cpds("Pollution"))
# Out:
# +--------------+-----+
# | Pollution(0) | 0.9 |
# +--------------+-----+
# | Pollution(1) | 0.1 |
# +--------------+-----+

# %%
print(cancer_model.get_cpds("Smoker"))
# Out:
# +-----------+-----+
# | Smoker(0) | 0.3 |
# +-----------+-----+
# | Smoker(1) | 0.7 |
# +-----------+-----+

# %%
print(cancer_model.get_cpds("Xray"))
# Out:
# +---------+-----------+-----------+
# | Cancer  | Cancer(0) | Cancer(1) |
# +---------+-----------+-----------+
# | Xray(0) | 0.9       | 0.2       |
# +---------+-----------+-----------+
# | Xray(1) | 0.1       | 0.8       |
# +---------+-----------+-----------+

# %%
print(cancer_model.get_cpds("Dyspnoea"))
# Out:
# +-------------+-----------+-----------+
# | Cancer      | Cancer(0) | Cancer(1) |
# +-------------+-----------+-----------+
# | Dyspnoea(0) | 0.65      | 0.3       |
# +-------------+-----------+-----------+
# | Dyspnoea(1) | 0.35      | 0.7       |
# +-------------+-----------+-----------+

# %%
print(cancer_model.get_cpds("Cancer"))
# Out:
# +-----------+--------------+--------------+--------------+--------------+
# | Smoker    | Smoker(0)    | Smoker(0)    | Smoker(1)    | Smoker(1)    |
# +-----------+--------------+--------------+--------------+--------------+
# | Pollution | Pollution(0) | Pollution(1) | Pollution(0) | Pollution(1) |
# +-----------+--------------+--------------+--------------+--------------+
# | Cancer(0) | 0.03         | 0.05         | 0.001        | 0.02         |
# +-----------+--------------+--------------+--------------+--------------+
# | Cancer(1) | 0.97         | 0.95         | 0.999        | 0.98         |
# +-----------+--------------+--------------+--------------+--------------+

# %%
cancer_model.local_independencies("Xray")
# Out:
# (Xray _|_ Pollution, Dyspnoea, Smoker | Cancer)

# %%
cancer_model.local_independencies("Pollution")
# Out:
# (Pollution _|_ Smoker)

# %%
cancer_model.local_independencies("Smoker")
# Out:
# (Smoker _|_ Pollution)

# %%
cancer_model.local_independencies("Dyspnoea")
# Out:
# (Dyspnoea _|_ Pollution, Smoker, Xray | Cancer)

# %%
cancer_model.local_independencies("Cancer")

# %%
cancer_model.get_independencies()
# Out:
# (Pollution _|_ Smoker)
# (Pollution _|_ Dyspnoea, Xray | Cancer)
# (Pollution _|_ Xray | Dyspnoea, Cancer)
# (Pollution _|_ Dyspnoea | Cancer, Xray)
# (Pollution _|_ Dyspnoea, Xray | Cancer, Smoker)
# (Pollution _|_ Xray | Dyspnoea, Cancer, Smoker)
# (Pollution _|_ Dyspnoea | Smoker, Cancer, Xray)
# (Smoker _|_ Pollution)
# (Smoker _|_ Dyspnoea, Xray | Cancer)
# (Smoker _|_ Dyspnoea, Xray | Pollution, Cancer)
# (Smoker _|_ Xray | Dyspnoea, Cancer)
# (Smoker _|_ Dyspnoea | Cancer, Xray)
# (Smoker _|_ Xray | Pollution, Dyspnoea, Cancer)
# (Smoker _|_ Dyspnoea | Pollution, Cancer, Xray)
# (Xray _|_ Pollution, Dyspnoea, Smoker | Cancer)
# (Xray _|_ Dyspnoea, Smoker | Pollution, Cancer)
# (Xray _|_ Pollution, Smoker | Dyspnoea, Cancer)
# (Xray _|_ Pollution, Dyspnoea | Cancer, Smoker)
# (Xray _|_ Smoker | Pollution, Dyspnoea, Cancer)
# (Xray _|_ Dyspnoea | Pollution, Cancer, Smoker)
# (Xray _|_ Pollution | Dyspnoea, Cancer, Smoker)
# (Dyspnoea _|_ Pollution, Smoker, Xray | Cancer)
# (Dyspnoea _|_ Smoker, Xray | Pollution, Cancer)
# (Dyspnoea _|_ Pollution, Smoker | Cancer, Xray)
# (Dyspnoea _|_ Pollution, Xray | Cancer, Smoker)
# (Dyspnoea _|_ Smoker | Pollution, Cancer, Xray)
# (Dyspnoea _|_ Xray | Pollution, Cancer, Smoker)
# (Dyspnoea _|_ Pollution | Smoker, Cancer, Xray)

# %%
from pgmpy.inference import VariableElimination

# %%
cancer_infr = VariableElimination(cancer_model)

# %%
q = cancer_infr.query(variables=["Cancer"], evidence={"Smoker": 1})
print(q)
# Out:
# Finding Elimination Order: : 100%|██████████| 3/3 [00:00<00:00, 191.95it/s]
# Eliminating: Xray: 100%|██████████| 3/3 [00:00<00:00, 273.47it/s]
# +-----------+---------------+
# | Cancer    |   phi(Cancer) |
# +===========+===============+
# | Cancer(0) |        0.0029 |
# +-----------+---------------+
# | Cancer(1) |        0.9971 |
# +-----------+---------------+

# %%
q = cancer_infr.query(variables=["Cancer"], evidence={"Smoker": 1, "Pollution": 1})
print(q)
# Out:
# Finding Elimination Order: : 100%|██████████| 2/2 [00:00<00:00, 1002.58it/s]
# Eliminating: Xray: 100%|██████████| 2/2 [00:00<00:00, 401.23it/s]
# +-----------+---------------+
# | Cancer    |   phi(Cancer) |
# +===========+===============+
# | Cancer(0) |        0.0200 |
# +-----------+---------------+
# | Cancer(1) |        0.9800 |
# +-----------+---------------+

# %% [markdown]
# # extra code

# %%
import numpy as np
from urllib.request import urlopen
import urllib
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as skl
import pandas as pd

# %%
data= "http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.hungarian.data"

# %%
names = ["age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal", "heartdisease"]

# %%
heartDisease = pd.read_csv(urlopen(data), names=names)
heartDisease.head()
# Out:
#    age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 0   28    1   2      130  132   0       2     185     0      0.0     ?  ?
# 1   29    1   2      120  243   0       0     160     0      0.0     ?  ?
# 2   29    1   2      140    ?   0       0     170     0      0.0     ?  ?
# 3   30    0   1      170  237   0       1     170     0      0.0     ?  ?
# 4   31    0   2      100  219   0       1     150     0      0.0     ?  ?
#
#   thal  heartdisease
# 0    ?             0
# 1    ?             0
# 2    ?             0
# 3    6             0
# 4    ?             0

# %%
del heartDisease["ca"]
del heartDisease["slope"]
del heartDisease["thal"]
del heartDisease["oldpeak"]

# %%
heartDisease = heartDisease.replace("?", np.nan)
heartDisease.dtypes
# Out:
# age              int64
# sex              int64
# cp               int64
# trestbps        object
# chol            object
# fbs             object
# restecg         object
# thalach         object
# exang           object
# heartdisease     int64
# dtype: object

# %%
heartDisease.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'heartdisease'],
#       dtype='object')

# %%
from pgmpy.models import BayesianModel
from pgmpy.estimators import MaximumLikelihoodEstimator, BayesianEstimator

# %%
model = BayesianModel([("age", "trestbps"),("age", "fbs"),("sex", "trestbps"),("sex", "trestbps"),("exang", "trestbps"),("trestbps", "heartdisease"),("fbs", "heartdisease"),("heartdisease", "restecg"),("heartdisease", "thalach"),("heartdisease", "thalach"),("heartdisease", "chol")])

# %%
model.fit(heartDisease, estimator=MaximumLikelihoodEstimator)
print(model.get_cpds("age"))
# Out:
# +---------+------------+
# | age(28) | 0.00383142 |
# +---------+------------+
# | age(29) | 0.00383142 |
# +---------+------------+
# | age(30) | 0.00383142 |
# +---------+------------+
# | age(31) | 0.00766284 |
# +---------+------------+
# | age(32) | 0.0153257  |
# +---------+------------+
# | age(33) | 0.00766284 |
# +---------+------------+
# | age(34) | 0.0153257  |
# +---------+------------+
# | age(35) | 0.0191571  |
# +---------+------------+
# | age(36) | 0.0191571  |
# +---------+------------+
# | age(37) | 0.0306513  |
# +---------+------------+
# | age(38) | 0.0191571  |
# +---------+------------+
# | age(39) | 0.0344828  |
# +---------+------------+
# | age(40) | 0.0191571  |
# +---------+------------+
# | age(41) | 0.0383142  |
# +---------+------------+
# | age(42) | 0.0268199  |
# +---------+------------+
# | age(43) | 0.0421456  |
# +---------+------------+
# | age(44) | 0.0268199  |
# +---------+------------+
# | age(45) | 0.0229885  |
# +---------+------------+
# | age(46) | 0.045977   |
# +---------+------------+
# | age(47) | 0.0344828  |
# +---------+------------+
# | age(48) | 0.0613027  |
# +---------+------------+
# | age(49) | 0.0421456  |
# +---------+------------+
# | age(50) | 0.045977   |
# +---------+------------+
# | age(51) | 0.0344828  |
# +---------+------------+
# | age(52) | 0.0574713  |
# +---------+------------+
# | age(53) | 0.0383142  |
# +---------+------------+
# | age(54) | 0.0842912  |
# +---------+------------+
# | age(55) | 0.0536398  |
# +---------+------------+
# | age(56) | 0.0306513  |
# +---------+------------+
# | age(57) | 0.0191571  |
# +---------+------------+
# | age(58) | 0.0344828  |
# +---------+------------+
# | age(59) | 0.0229885  |
# +---------+------------+
# | age(60) | 0.00766284 |
# +---------+------------+
# | age(61) | 0.00766284 |
# +---------+------------+
# | age(62) | 0.00766284 |
# +---------+------------+
# | age(63) | 0.00383142 |
# +---------+------------+
# | age(65) | 0.0114943  |
# +---------+------------+
# | age(66) | 0          |
# +---------+------------+

# %%
print(model.get_cpds("chol"))
# Out:
# +--------------+----------------------+----------------------+
# | heartdisease | heartdisease(0)      | heartdisease(1)      |
# +--------------+----------------------+----------------------+
# | chol(100)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(117)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(129)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(132)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(147)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(156)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(160)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(161)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(163)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(164)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(166)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(167)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(168)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(171)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(172)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(173)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(175)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(179)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(180)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(182)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(184)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(186)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(187)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(188)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(190)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(193)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(194)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(195)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(196)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(198)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(200)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(201)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(202)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(204)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(205)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(206)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(207)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(208)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(209)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(210)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(211)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(212)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(213)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(214)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(215)    | 0.024539877300613498 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(216)    | 0.012269938650306749 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(217)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(218)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(219)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(220)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(221)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(222)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(223)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(224)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(225)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(226)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(227)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(228)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(229)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(230)    | 0.024539877300613498 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(231)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(233)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(234)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(237)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(238)    | 0.024539877300613498 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(240)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(241)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(242)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(243)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(245)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(246)    | 0.012269938650306749 | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(247)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(248)    | 0.0                  | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(249)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(250)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(251)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(253)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(254)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(255)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(256)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(257)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(259)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(260)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(263)    | 0.006134969325153374 | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(264)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(265)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(266)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(267)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(268)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(269)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(270)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(271)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(272)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(273)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(274)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(275)    | 0.012269938650306749 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(276)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(277)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(279)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(280)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(281)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(282)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(283)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(284)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(285)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(287)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(288)    | 0.0                  | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(289)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(290)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(291)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(292)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(294)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(295)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(297)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(298)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(303)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(305)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(306)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(307)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(308)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(309)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(312)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(315)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(318)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(320)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(326)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(328)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(329)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(331)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(336)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(338)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(339)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(340)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(341)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(342)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(344)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(347)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(355)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(358)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(365)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(388)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(392)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(393)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(394)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(404)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(412)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(466)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(468)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(491)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(518)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(529)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(603)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(85)     | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+

# %%
print(model.get_cpds("sex"))
# Out:
# +--------+----------+
# | sex(0) | 0.264368 |
# +--------+----------+
# | sex(1) | 0.735632 |
# +--------+----------+

# %%
model.get_independencies()
# Out:
# (age _|_ exang, sex)
# (age _|_ exang | sex)
# (age _|_ sex | exang)
# (age _|_ restecg, chol, thalach | heartdisease)
# (age _|_ exang, sex | fbs)
# (age _|_ chol, thalach | restecg, heartdisease)
# (age _|_ restecg, chol, thalach | sex, heartdisease)
# (age _|_ exang | fbs, sex)
# (age _|_ restecg, chol, thalach | exang, heartdisease)
# (age _|_ sex | fbs, exang)
# (age _|_ restecg, chol, thalach | trestbps, heartdisease)
# (age _|_ restecg, chol, thalach, heartdisease | trestbps, fbs)
# (age _|_ restecg, thalach | chol, heartdisease)
# (age _|_ restecg, chol | thalach, heartdisease)
# (age _|_ restecg, chol, thalach | fbs, heartdisease)
# (age _|_ chol, thalach | restecg, sex, heartdisease)
# (age _|_ chol, thalach | restecg, exang, heartdisease)
# (age _|_ chol, thalach | restecg, trestbps, heartdisease)
# (age _|_ chol, thalach, heartdisease | restecg, fbs, trestbps)
# (age _|_ thalach | restecg, chol, heartdisease)
# (age _|_ chol | restecg, thalach, heartdisease)
# (age _|_ chol, thalach | restecg, fbs, heartdisease)
# (age _|_ restecg, chol, thalach | exang, sex, heartdisease)
# (age _|_ restecg, chol, thalach | trestbps, sex, heartdisease)
# (age _|_ restecg, chol, thalach, heartdisease | trestbps, fbs, sex)
# (age _|_ restecg, thalach | chol, sex, heartdisease)
# (age _|_ restecg, chol | thalach, sex, heartdisease)
# (age _|_ restecg, chol, thalach | fbs, sex, heartdisease)
# (age _|_ restecg, chol, thalach | trestbps, exang, heartdisease)
# (age _|_ restecg, chol, thalach, heartdisease | trestbps, fbs, exang)
# (age _|_ restecg, thalach | chol, exang, heartdisease)
# (age _|_ restecg, chol | thalach, exang, heartdisease)
# (age _|_ restecg, chol, thalach | fbs, exang, heartdisease)
# (age _|_ restecg, thalach | trestbps, chol, heartdisease)
# (age _|_ restecg, thalach, heartdisease | trestbps, chol, fbs)
# (age _|_ restecg, chol | trestbps, thalach, heartdisease)
# (age _|_ restecg, chol, heartdisease | trestbps, fbs, thalach)
# (age _|_ restecg, chol, thalach | trestbps, fbs, heartdisease)
# (age _|_ restecg | chol, thalach, heartdisease)
# (age _|_ restecg, thalach | chol, fbs, heartdisease)
# (age _|_ restecg, chol | fbs, thalach, heartdisease)
# (age _|_ chol, thalach | restecg, exang, sex, heartdisease)
# (age _|_ chol, thalach | trestbps, restecg, sex, heartdisease)
# (age _|_ chol, thalach, heartdisease | trestbps, restecg, fbs, sex)
# (age _|_ thalach | restecg, chol, sex, heartdisease)
# (age _|_ chol | restecg, thalach, sex, heartdisease)
# (age _|_ chol, thalach | restecg, fbs, sex, heartdisease)
# (age _|_ chol, thalach | restecg, exang, trestbps, heartdisease)
# (age _|_ chol, thalach, heartdisease | restecg, fbs, exang, trestbps)
# (age _|_ thalach | restecg, chol, exang, heartdisease)
# (age _|_ chol | thalach, restecg, exang, heartdisease)
# (age _|_ chol, thalach | restecg, fbs, exang, heartdisease)
# (age _|_ thalach | restecg, chol, trestbps, heartdisease)
# (age _|_ thalach, heartdisease | restecg, chol, fbs, trestbps)
# (age _|_ chol | restecg, thalach, trestbps, heartdisease)
# (age _|_ chol, heartdisease | restecg, fbs, thalach, trestbps)
# (age _|_ chol, thalach | restecg, fbs, trestbps, heartdisease)
# (age _|_ thalach | restecg, chol, fbs, heartdisease)
# (age _|_ chol | restecg, fbs, thalach, heartdisease)
# (age _|_ restecg, chol, thalach | trestbps, exang, sex, heartdisease)
# (age _|_ restecg, chol, thalach, heartdisease | trestbps, fbs, exang, sex)
# (age _|_ restecg, thalach | chol, exang, sex, heartdisease)
# (age _|_ restecg, chol | thalach, exang, sex, heartdisease)
# (age _|_ restecg, chol, thalach | fbs, exang, sex, heartdisease)
# (age _|_ restecg, thalach | trestbps, chol, sex, heartdisease)
# (age _|_ restecg, thalach, heartdisease | trestbps, chol, fbs, sex)
# (age _|_ restecg, chol | trestbps, thalach, sex, heartdisease)
# (age _|_ restecg, chol, heartdisease | trestbps, fbs, thalach, sex)
# (age _|_ restecg, chol, thalach | trestbps, fbs, sex, heartdisease)
# (age _|_ restecg | chol, thalach, sex, heartdisease)
# (age _|_ restecg, thalach | chol, fbs, sex, heartdisease)
# (age _|_ restecg, chol | fbs, thalach, sex, heartdisease)
# (age _|_ restecg, thalach | trestbps, chol, exang, heartdisease)
# (age _|_ restecg, thalach, heartdisease | trestbps, chol, exang, fbs)
# (age _|_ restecg, chol | thalach, trestbps, exang, heartdisease)
# (age _|_ restecg, chol, heartdisease | thalach, trestbps, fbs, exang)
# (age _|_ restecg, chol, thalach | trestbps, fbs, exang, heartdisease)
# (age _|_ restecg | thalach, chol, exang, heartdisease)
# (age _|_ restecg, thalach | chol, exang, fbs, heartdisease)
# (age _|_ restecg, chol | thalach, fbs, exang, heartdisease)
# (age _|_ restecg | trestbps, chol, thalach, heartdisease)
# (age _|_ restecg, heartdisease | trestbps, chol, thalach, fbs)
# (age _|_ restecg, thalach | trestbps, chol, fbs, heartdisease)
# (age _|_ restecg, chol | trestbps, fbs, thalach, heartdisease)
# (age _|_ restecg | chol, thalach, fbs, heartdisease)
# (age _|_ chol, thalach | restecg, sex, exang, trestbps, heartdisease)
# (age _|_ chol, thalach, heartdisease | restecg, sex, exang, trestbps, fbs)
# (age _|_ thalach | restecg, sex, exang, chol, heartdisease)
# (age _|_ chol | restecg, sex, exang, thalach, heartdisease)
# (age _|_ chol, thalach | restecg, sex, exang, heartdisease, fbs)
# (age _|_ thalach | restecg, sex, trestbps, chol, heartdisease)
# (age _|_ thalach, heartdisease | restecg, sex, trestbps, chol, fbs)
# (age _|_ chol | restecg, sex, trestbps, thalach, heartdisease)
# (age _|_ chol, heartdisease | restecg, sex, trestbps, thalach, fbs)
# (age _|_ chol, thalach | restecg, sex, trestbps, heartdisease, fbs)
# (age _|_ thalach | restecg, sex, chol, heartdisease, fbs)
# (age _|_ chol | restecg, sex, thalach, heartdisease, fbs)
# (age _|_ thalach | restecg, exang, trestbps, chol, heartdisease)
# (age _|_ thalach, heartdisease | restecg, exang, trestbps, chol, fbs)
# (age _|_ chol | restecg, exang, trestbps, thalach, heartdisease)
# (age _|_ chol, heartdisease | restecg, exang, trestbps, thalach, fbs)
# (age _|_ chol, thalach | restecg, exang, trestbps, heartdisease, fbs)
# (age _|_ thalach | restecg, exang, chol, heartdisease, fbs)
# (age _|_ chol | restecg, exang, thalach, heartdisease, fbs)
# (age _|_ heartdisease | restecg, trestbps, chol, thalach, fbs)
# (age _|_ thalach | restecg, trestbps, chol, heartdisease, fbs)
# (age _|_ chol | restecg, trestbps, thalach, heartdisease, fbs)
# (age _|_ restecg, thalach | sex, exang, trestbps, chol, heartdisease)
# (age _|_ restecg, thalach, heartdisease | sex, exang, trestbps, chol, fbs)
# (age _|_ restecg, chol | sex, exang, trestbps, thalach, heartdisease)
# (age _|_ restecg, chol, heartdisease | sex, exang, trestbps, thalach, fbs)
# (age _|_ restecg, chol, thalach | sex, exang, trestbps, heartdisease, fbs)
# (age _|_ restecg | sex, exang, chol, thalach, heartdisease)
# (age _|_ restecg, thalach | sex, exang, chol, heartdisease, fbs)
# (age _|_ restecg, chol | sex, exang, thalach, heartdisease, fbs)
# (age _|_ restecg | sex, trestbps, chol, thalach, heartdisease)
# (age _|_ restecg, heartdisease | sex, trestbps, chol, thalach, fbs)
# (age _|_ restecg, thalach | sex, trestbps, chol, heartdisease, fbs)
# (age _|_ restecg, chol | sex, trestbps, thalach, heartdisease, fbs)
# (age _|_ restecg | sex, chol, thalach, heartdisease, fbs)
# (age _|_ restecg | exang, trestbps, chol, thalach, heartdisease)
# (age _|_ restecg, heartdisease | exang, trestbps, chol, thalach, fbs)
# (age _|_ restecg, thalach | exang, trestbps, chol, heartdisease, fbs)
# (age _|_ restecg, chol | exang, trestbps, thalach, heartdisease, fbs)
# (age _|_ restecg | exang, chol, thalach, heartdisease, fbs)
# (age _|_ restecg | trestbps, chol, thalach, heartdisease, fbs)
# (age _|_ thalach | restecg, sex, exang, trestbps, chol, heartdisease)
# (age _|_ thalach, heartdisease | restecg, sex, exang, trestbps, chol, fbs)
# (age _|_ chol | restecg, sex, exang, trestbps, thalach, heartdisease)
# (age _|_ chol, heartdisease | restecg, sex, exang, trestbps, thalach, fbs)
# (age _|_ chol, thalach | restecg, sex, exang, trestbps, heartdisease, fbs)
# (age _|_ thalach | restecg, sex, exang, chol, heartdisease, fbs)
# (age _|_ chol | restecg, sex, exang, thalach, heartdisease, fbs)
# (age _|_ heartdisease | restecg, sex, trestbps, chol, thalach, fbs)
# (age _|_ thalach | restecg, sex, trestbps, chol, heartdisease, fbs)
# (age _|_ chol | restecg, sex, trestbps, thalach, heartdisease, fbs)
# (age _|_ heartdisease | restecg, exang, trestbps, chol, thalach, fbs)
# (age _|_ thalach | restecg, exang, trestbps, chol, heartdisease, fbs)
# (age _|_ chol | restecg, exang, trestbps, thalach, heartdisease, fbs)
# (age _|_ restecg | sex, exang, trestbps, chol, thalach, heartdisease)
# (age _|_ restecg, heartdisease | sex, exang, trestbps, chol, thalach, fbs)
# (age _|_ restecg, thalach | sex, exang, trestbps, chol, heartdisease, fbs)
# (age _|_ restecg, chol | sex, exang, trestbps, thalach, heartdisease, fbs)
# (age _|_ restecg | sex, exang, chol, thalach, heartdisease, fbs)
# (age _|_ restecg | sex, trestbps, chol, thalach, heartdisease, fbs)
# (age _|_ restecg | exang, trestbps, chol, thalach, heartdisease, fbs)
# (age _|_ heartdisease | restecg, sex, exang, trestbps, chol, thalach, fbs)
# (age _|_ thalach | restecg, sex, exang, trestbps, chol, heartdisease, fbs)
# (age _|_ chol | restecg, sex, exang, trestbps, thalach, heartdisease, fbs)
# (age _|_ restecg | sex, exang, trestbps, chol, thalach, heartdisease, fbs)
# (trestbps _|_ fbs | age)
# (trestbps _|_ restecg, chol, thalach | heartdisease)
# (trestbps _|_ chol, thalach | restecg, heartdisease)
# (trestbps _|_ fbs | age, sex)
# (trestbps _|_ restecg, chol, thalach | sex, heartdisease)
# (trestbps _|_ fbs | age, exang)
# (trestbps _|_ restecg, chol, thalach | exang, heartdisease)
# (trestbps _|_ restecg, chol, thalach | age, heartdisease)
# (trestbps _|_ restecg, thalach | chol, heartdisease)
# (trestbps _|_ restecg, chol | thalach, heartdisease)
# (trestbps _|_ restecg, chol, thalach | fbs, heartdisease)
# (trestbps _|_ chol, thalach | restecg, sex, heartdisease)
# (trestbps _|_ chol, thalach | restecg, exang, heartdisease)
# (trestbps _|_ chol, thalach | age, restecg, heartdisease)
# (trestbps _|_ thalach | restecg, chol, heartdisease)
# (trestbps _|_ chol | restecg, thalach, heartdisease)
# (trestbps _|_ chol, thalach | restecg, fbs, heartdisease)
# (trestbps _|_ fbs | age, exang, sex)
# (trestbps _|_ restecg, chol, thalach | exang, sex, heartdisease)
# (trestbps _|_ restecg, chol, thalach | age, sex, heartdisease)
# (trestbps _|_ restecg, thalach | chol, sex, heartdisease)
# (trestbps _|_ restecg, chol | thalach, sex, heartdisease)
# (trestbps _|_ restecg, chol, thalach | fbs, sex, heartdisease)
# (trestbps _|_ restecg, chol, thalach | age, exang, heartdisease)
# (trestbps _|_ restecg, thalach | chol, exang, heartdisease)
# (trestbps _|_ restecg, chol | thalach, exang, heartdisease)
# (trestbps _|_ restecg, chol, thalach | fbs, exang, heartdisease)
# (trestbps _|_ restecg, thalach | age, chol, heartdisease)
# (trestbps _|_ restecg, chol | age, thalach, heartdisease)
# (trestbps _|_ restecg, chol, thalach | age, fbs, heartdisease)
# (trestbps _|_ restecg | chol, thalach, heartdisease)
# (trestbps _|_ restecg, thalach | chol, fbs, heartdisease)
# (trestbps _|_ restecg, chol | fbs, thalach, heartdisease)
# (trestbps _|_ chol, thalach | restecg, exang, sex, heartdisease)
# (trestbps _|_ chol, thalach | age, restecg, sex, heartdisease)
# (trestbps _|_ thalach | restecg, chol, sex, heartdisease)
# (trestbps _|_ chol | restecg, thalach, sex, heartdisease)
# (trestbps _|_ chol, thalach | restecg, fbs, sex, heartdisease)
# (trestbps _|_ chol, thalach | age, restecg, exang, heartdisease)
# (trestbps _|_ thalach | restecg, chol, exang, heartdisease)
# (trestbps _|_ chol | thalach, restecg, exang, heartdisease)
# (trestbps _|_ chol, thalach | restecg, fbs, exang, heartdisease)
# (trestbps _|_ thalach | age, restecg, chol, heartdisease)
# (trestbps _|_ chol | age, restecg, thalach, heartdisease)
# (trestbps _|_ chol, thalach | age, restecg, fbs, heartdisease)
# (trestbps _|_ thalach | restecg, chol, fbs, heartdisease)
# (trestbps _|_ chol | restecg, fbs, thalach, heartdisease)
# (trestbps _|_ restecg, chol, thalach | age, exang, sex, heartdisease)
# (trestbps _|_ restecg, thalach | chol, exang, sex, heartdisease)
# (trestbps _|_ restecg, chol | thalach, exang, sex, heartdisease)
# (trestbps _|_ restecg, chol, thalach | fbs, exang, sex, heartdisease)
# (trestbps _|_ restecg, thalach | age, chol, sex, heartdisease)
# (trestbps _|_ restecg, chol | age, thalach, sex, heartdisease)
# (trestbps _|_ restecg, chol, thalach | age, fbs, sex, heartdisease)
# (trestbps _|_ restecg | chol, thalach, sex, heartdisease)
# (trestbps _|_ restecg, thalach | chol, fbs, sex, heartdisease)
# (trestbps _|_ restecg, chol | fbs, thalach, sex, heartdisease)
# (trestbps _|_ restecg, thalach | age, chol, exang, heartdisease)
# (trestbps _|_ restecg, chol | age, thalach, exang, heartdisease)
# (trestbps _|_ restecg, chol, thalach | age, fbs, exang, heartdisease)
# (trestbps _|_ restecg | thalach, chol, exang, heartdisease)
# (trestbps _|_ restecg, thalach | chol, exang, fbs, heartdisease)
# (trestbps _|_ restecg, chol | thalach, fbs, exang, heartdisease)
# (trestbps _|_ restecg | age, chol, thalach, heartdisease)
# (trestbps _|_ restecg, thalach | age, chol, fbs, heartdisease)
# (trestbps _|_ restecg, chol | age, fbs, thalach, heartdisease)
# (trestbps _|_ restecg | chol, thalach, fbs, heartdisease)
# (trestbps _|_ chol, thalach | restecg, sex, exang, age, heartdisease)
# (trestbps _|_ thalach | restecg, sex, exang, chol, heartdisease)
# (trestbps _|_ chol | restecg, sex, exang, thalach, heartdisease)
# (trestbps _|_ chol, thalach | restecg, sex, exang, heartdisease, fbs)
# (trestbps _|_ thalach | restecg, sex, age, chol, heartdisease)
# (trestbps _|_ chol | restecg, sex, age, thalach, heartdisease)
# (trestbps _|_ chol, thalach | restecg, sex, age, heartdisease, fbs)
# (trestbps _|_ thalach | restecg, sex, chol, heartdisease, fbs)
# (trestbps _|_ chol | restecg, sex, thalach, heartdisease, fbs)
# (trestbps _|_ thalach | restecg, exang, age, chol, heartdisease)
# (trestbps _|_ chol | restecg, exang, age, thalach, heartdisease)
# (trestbps _|_ chol, thalach | restecg, exang, age, heartdisease, fbs)
# (trestbps _|_ thalach | restecg, exang, chol, heartdisease, fbs)
# (trestbps _|_ chol | restecg, exang, thalach, heartdisease, fbs)
# (trestbps _|_ thalach | restecg, age, chol, heartdisease, fbs)
# (trestbps _|_ chol | restecg, age, thalach, heartdisease, fbs)
# (trestbps _|_ restecg, thalach | sex, exang, age, chol, heartdisease)
# (trestbps _|_ restecg, chol | sex, exang, age, thalach, heartdisease)
# (trestbps _|_ restecg, chol, thalach | sex, exang, age, heartdisease, fbs)
# (trestbps _|_ restecg | sex, exang, chol, thalach, heartdisease)
# (trestbps _|_ restecg, thalach | sex, exang, chol, heartdisease, fbs)
# (trestbps _|_ restecg, chol | sex, exang, thalach, heartdisease, fbs)
# (trestbps _|_ restecg | sex, age, chol, thalach, heartdisease)
# (trestbps _|_ restecg, thalach | sex, age, chol, heartdisease, fbs)
# (trestbps _|_ restecg, chol | sex, age, thalach, heartdisease, fbs)
# (trestbps _|_ restecg | sex, chol, thalach, heartdisease, fbs)
# (trestbps _|_ restecg | exang, age, chol, thalach, heartdisease)
# (trestbps _|_ restecg, thalach | exang, age, chol, heartdisease, fbs)
# (trestbps _|_ restecg, chol | exang, age, thalach, heartdisease, fbs)
# (trestbps _|_ restecg | exang, chol, thalach, heartdisease, fbs)
# (trestbps _|_ restecg | age, chol, thalach, heartdisease, fbs)
# (trestbps _|_ thalach | restecg, sex, exang, age, chol, heartdisease)
# (trestbps _|_ chol | restecg, sex, exang, age, thalach, heartdisease)
# (trestbps _|_ chol, thalach | restecg, sex, exang, age, heartdisease, fbs)
# (trestbps _|_ thalach | restecg, sex, exang, chol, heartdisease, fbs)
# (trestbps _|_ chol | restecg, sex, exang, thalach, heartdisease, fbs)
# (trestbps _|_ thalach | restecg, sex, age, chol, heartdisease, fbs)
# (trestbps _|_ chol | restecg, sex, age, thalach, heartdisease, fbs)
# (trestbps _|_ thalach | restecg, exang, age, chol, heartdisease, fbs)
# (trestbps _|_ chol | restecg, exang, age, thalach, heartdisease, fbs)
# (trestbps _|_ restecg | sex, exang, age, chol, thalach, heartdisease)
# (trestbps _|_ restecg, thalach | sex, exang, age, chol, heartdisease, fbs)
# (trestbps _|_ restecg, chol | sex, exang, age, thalach, heartdisease, fbs)
# (trestbps _|_ restecg | sex, exang, chol, thalach, heartdisease, fbs)
# (trestbps _|_ restecg | sex, age, chol, thalach, heartdisease, fbs)
# (trestbps _|_ restecg | exang, age, chol, thalach, heartdisease, fbs)
# (trestbps _|_ thalach | restecg, sex, exang, age, chol, heartdisease, fbs)
# (trestbps _|_ chol | restecg, sex, exang, age, thalach, heartdisease, fbs)
# (trestbps _|_ restecg | sex, exang, age, chol, thalach, heartdisease, fbs)
# (fbs _|_ exang, sex)
# (fbs _|_ exang | sex)
# (fbs _|_ sex | exang)
# (fbs _|_ trestbps, exang, sex | age)
# (fbs _|_ restecg, chol, thalach | heartdisease)
# (fbs _|_ chol, thalach | restecg, heartdisease)
# (fbs _|_ trestbps, exang | age, sex)
# (fbs _|_ restecg, chol, thalach | sex, heartdisease)
# (fbs _|_ trestbps, sex | age, exang)
# (fbs _|_ restecg, chol, thalach | exang, heartdisease)
# (fbs _|_ exang, sex | age, trestbps)
# (fbs _|_ restecg, chol, thalach | age, heartdisease)
# (fbs _|_ restecg, chol, thalach | trestbps, heartdisease)
# (fbs _|_ restecg, thalach | chol, heartdisease)
# (fbs _|_ restecg, chol | thalach, heartdisease)
# (fbs _|_ chol, thalach | restecg, sex, heartdisease)
# (fbs _|_ chol, thalach | restecg, exang, heartdisease)
# (fbs _|_ exang, sex | age, restecg, trestbps)
# (fbs _|_ chol, thalach | age, restecg, heartdisease)
# (fbs _|_ chol, thalach | restecg, trestbps, heartdisease)
# (fbs _|_ thalach | restecg, chol, heartdisease)
# (fbs _|_ chol | restecg, thalach, heartdisease)
# (fbs _|_ trestbps | age, exang, sex)
# (fbs _|_ restecg, chol, thalach | exang, sex, heartdisease)
# (fbs _|_ exang | age, trestbps, sex)
# (fbs _|_ restecg, chol, thalach | age, sex, heartdisease)
# (fbs _|_ restecg, chol, thalach | trestbps, sex, heartdisease)
# (fbs _|_ restecg, thalach | chol, sex, heartdisease)
# (fbs _|_ restecg, chol | thalach, sex, heartdisease)
# (fbs _|_ sex | age, trestbps, exang)
# (fbs _|_ restecg, chol, thalach | age, exang, heartdisease)
# (fbs _|_ restecg, chol, thalach | trestbps, exang, heartdisease)
# (fbs _|_ restecg, thalach | chol, exang, heartdisease)
# (fbs _|_ restecg, chol | thalach, exang, heartdisease)
# (fbs _|_ exang, sex | age, trestbps, chol)
# (fbs _|_ exang, sex | age, trestbps, thalach)
# (fbs _|_ restecg, chol, thalach, sex, exang | age, trestbps, heartdisease)
# (fbs _|_ restecg, thalach | age, chol, heartdisease)
# (fbs _|_ restecg, chol | age, thalach, heartdisease)
# (fbs _|_ restecg, thalach | trestbps, chol, heartdisease)
# (fbs _|_ restecg, chol | trestbps, thalach, heartdisease)
# (fbs _|_ restecg | chol, thalach, heartdisease)
# (fbs _|_ chol, thalach | restecg, exang, sex, heartdisease)
# (fbs _|_ exang | age, restecg, sex, trestbps)
# (fbs _|_ chol, thalach | age, restecg, sex, heartdisease)
# (fbs _|_ chol, thalach | trestbps, restecg, sex, heartdisease)
# (fbs _|_ thalach | restecg, chol, sex, heartdisease)
# (fbs _|_ chol | restecg, thalach, sex, heartdisease)
# (fbs _|_ sex | age, restecg, exang, trestbps)
# (fbs _|_ chol, thalach | age, restecg, exang, heartdisease)
# (fbs _|_ chol, thalach | restecg, exang, trestbps, heartdisease)
# (fbs _|_ thalach | restecg, chol, exang, heartdisease)
# (fbs _|_ chol | thalach, restecg, exang, heartdisease)
# (fbs _|_ exang, sex | age, restecg, chol, trestbps)
# (fbs _|_ exang, sex | age, restecg, thalach, trestbps)
# (fbs _|_ chol, thalach, exang, sex | age, restecg, trestbps, heartdisease)
# (fbs _|_ thalach | age, restecg, chol, heartdisease)
# (fbs _|_ chol | age, restecg, thalach, heartdisease)
# (fbs _|_ thalach | restecg, chol, trestbps, heartdisease)
# (fbs _|_ chol | restecg, thalach, trestbps, heartdisease)
# (fbs _|_ restecg, chol, thalach | age, exang, sex, heartdisease)
# (fbs _|_ restecg, chol, thalach | trestbps, exang, sex, heartdisease)
# (fbs _|_ restecg, thalach | chol, exang, sex, heartdisease)
# (fbs _|_ restecg, chol | thalach, exang, sex, heartdisease)
# (fbs _|_ exang | age, trestbps, chol, sex)
# (fbs _|_ exang | age, trestbps, thalach, sex)
# (fbs _|_ restecg, chol, thalach, exang | age, trestbps, sex, heartdisease)
# (fbs _|_ restecg, thalach | age, chol, sex, heartdisease)
# (fbs _|_ restecg, chol | age, thalach, sex, heartdisease)
# (fbs _|_ restecg, thalach | trestbps, chol, sex, heartdisease)
# (fbs _|_ restecg, chol | trestbps, thalach, sex, heartdisease)
# (fbs _|_ restecg | chol, thalach, sex, heartdisease)
# (fbs _|_ sex | age, trestbps, chol, exang)
# (fbs _|_ sex | age, trestbps, exang, thalach)
# (fbs _|_ restecg, chol, thalach, sex | age, trestbps, exang, heartdisease)
# (fbs _|_ restecg, thalach | age, chol, exang, heartdisease)
# (fbs _|_ restecg, chol | age, thalach, exang, heartdisease)
# (fbs _|_ restecg, thalach | trestbps, chol, exang, heartdisease)
# (fbs _|_ restecg, chol | thalach, trestbps, exang, heartdisease)
# (fbs _|_ restecg | thalach, chol, exang, heartdisease)
# (fbs _|_ exang, sex | age, trestbps, chol, thalach)
# (fbs _|_ restecg, exang, thalach, sex | age, trestbps, chol, heartdisease)
# (fbs _|_ restecg, chol, exang, sex | age, trestbps, thalach, heartdisease)
# (fbs _|_ restecg | age, chol, thalach, heartdisease)
# (fbs _|_ restecg | trestbps, chol, thalach, heartdisease)
# (fbs _|_ chol, thalach | restecg, sex, exang, age, heartdisease)
# (fbs _|_ chol, thalach | restecg, sex, exang, trestbps, heartdisease)
# (fbs _|_ thalach | restecg, sex, exang, chol, heartdisease)
# (fbs _|_ chol | restecg, sex, exang, thalach, heartdisease)
# (fbs _|_ exang | restecg, sex, age, trestbps, chol)
# (fbs _|_ exang | restecg, sex, age, trestbps, thalach)
# (fbs _|_ chol, thalach, exang | restecg, sex, age, trestbps, heartdisease)
# (fbs _|_ thalach | restecg, sex, age, chol, heartdisease)
# (fbs _|_ chol | restecg, sex, age, thalach, heartdisease)
# (fbs _|_ thalach | restecg, sex, trestbps, chol, heartdisease)
# (fbs _|_ chol | restecg, sex, trestbps, thalach, heartdisease)
# (fbs _|_ sex | restecg, exang, age, trestbps, chol)
# (fbs _|_ sex | restecg, exang, age, trestbps, thalach)
# (fbs _|_ chol, thalach, sex | restecg, exang, age, trestbps, heartdisease)
# (fbs _|_ thalach | restecg, exang, age, chol, heartdisease)
# (fbs _|_ chol | restecg, exang, age, thalach, heartdisease)
# (fbs _|_ thalach | restecg, exang, trestbps, chol, heartdisease)
# (fbs _|_ chol | restecg, exang, trestbps, thalach, heartdisease)
# (fbs _|_ exang, sex | restecg, age, trestbps, chol, thalach)
# (fbs _|_ exang, thalach, sex | restecg, age, trestbps, chol, heartdisease)
# (fbs _|_ chol, exang, sex | restecg, age, trestbps, thalach, heartdisease)
# (fbs _|_ restecg, chol, thalach | sex, exang, age, trestbps, heartdisease)
# (fbs _|_ restecg, thalach | sex, exang, age, chol, heartdisease)
# (fbs _|_ restecg, chol | sex, exang, age, thalach, heartdisease)
# (fbs _|_ restecg, thalach | sex, exang, trestbps, chol, heartdisease)
# (fbs _|_ restecg, chol | sex, exang, trestbps, thalach, heartdisease)
# (fbs _|_ restecg | sex, exang, chol, thalach, heartdisease)
# (fbs _|_ exang | sex, age, trestbps, chol, thalach)
# (fbs _|_ restecg, exang, thalach | sex, age, trestbps, chol, heartdisease)
# (fbs _|_ restecg, chol, exang | sex, age, trestbps, thalach, heartdisease)
# (fbs _|_ restecg | sex, age, chol, thalach, heartdisease)
# (fbs _|_ restecg | sex, trestbps, chol, thalach, heartdisease)
# (fbs _|_ sex | exang, age, trestbps, chol, thalach)
# (fbs _|_ restecg, thalach, sex | exang, age, trestbps, chol, heartdisease)
# (fbs _|_ restecg, chol, sex | exang, age, trestbps, thalach, heartdisease)
# (fbs _|_ restecg | exang, age, chol, thalach, heartdisease)
# (fbs _|_ restecg | exang, trestbps, chol, thalach, heartdisease)
# (fbs _|_ restecg, exang, sex | age, trestbps, chol, thalach, heartdisease)
# (fbs _|_ chol, thalach | restecg, sex, exang, age, trestbps, heartdisease)
# (fbs _|_ thalach | restecg, sex, exang, age, chol, heartdisease)
# (fbs _|_ chol | restecg, sex, exang, age, thalach, heartdisease)
# (fbs _|_ thalach | restecg, sex, exang, trestbps, chol, heartdisease)
# (fbs _|_ chol | restecg, sex, exang, trestbps, thalach, heartdisease)
# (fbs _|_ exang | restecg, sex, age, trestbps, chol, thalach)
# (fbs _|_ exang, thalach | restecg, sex, age, trestbps, chol, heartdisease)
# (fbs _|_ chol, exang | restecg, sex, age, trestbps, thalach, heartdisease)
# (fbs _|_ sex | restecg, exang, age, trestbps, chol, thalach)
# (fbs _|_ thalach, sex | restecg, exang, age, trestbps, chol, heartdisease)
# (fbs _|_ chol, sex | restecg, exang, age, trestbps, thalach, heartdisease)
# (fbs _|_ exang, sex | restecg, age, trestbps, chol, thalach, heartdisease)
# (fbs _|_ restecg, thalach | sex, exang, age, trestbps, chol, heartdisease)
# (fbs _|_ restecg, chol | sex, exang, age, trestbps, thalach, heartdisease)
# (fbs _|_ restecg | sex, exang, age, chol, thalach, heartdisease)
# (fbs _|_ restecg | sex, exang, trestbps, chol, thalach, heartdisease)
# (fbs _|_ restecg, exang | sex, age, trestbps, chol, thalach, heartdisease)
# (fbs _|_ restecg, sex | exang, age, trestbps, chol, thalach, heartdisease)
# (fbs _|_ thalach | restecg, sex, exang, age, trestbps, chol, heartdisease)
# (fbs _|_ chol | restecg, sex, exang, age, trestbps, thalach, heartdisease)
# (fbs _|_ exang | restecg, sex, age, trestbps, chol, thalach, heartdisease)
# (fbs _|_ sex | restecg, exang, age, trestbps, chol, thalach, heartdisease)
# (fbs _|_ restecg | sex, exang, age, trestbps, chol, thalach, heartdisease)
# (sex _|_ age, fbs, exang)
# (sex _|_ age, fbs | exang)
# (sex _|_ fbs, exang | age)
# (sex _|_ restecg, chol, thalach | heartdisease)
# (sex _|_ age, exang | fbs)
# (sex _|_ chol, thalach | restecg, heartdisease)
# (sex _|_ fbs | age, exang)
# (sex _|_ restecg, chol, thalach | exang, heartdisease)
# (sex _|_ age | fbs, exang)
# (sex _|_ restecg, chol, thalach, heartdisease, fbs | age, trestbps)
# (sex _|_ restecg, chol, thalach | age, heartdisease)
# (sex _|_ exang | age, fbs)
# (sex _|_ restecg, chol, thalach | trestbps, heartdisease)
# (sex _|_ restecg, chol, thalach, heartdisease | trestbps, fbs)
# (sex _|_ restecg, thalach | chol, heartdisease)
# (sex _|_ restecg, chol | thalach, heartdisease)
# (sex _|_ restecg, chol, thalach | fbs, heartdisease)
# (sex _|_ chol, thalach | restecg, exang, heartdisease)
# (sex _|_ chol, thalach, fbs, heartdisease | age, restecg, trestbps)
# (sex _|_ chol, thalach | age, restecg, heartdisease)
# (sex _|_ chol, thalach | restecg, trestbps, heartdisease)
# (sex _|_ chol, thalach, heartdisease | restecg, fbs, trestbps)
# (sex _|_ thalach | restecg, chol, heartdisease)
# (sex _|_ chol | restecg, thalach, heartdisease)
# (sex _|_ chol, thalach | restecg, fbs, heartdisease)
# (sex _|_ restecg, chol, thalach, heartdisease, fbs | age, trestbps, exang)
# (sex _|_ restecg, chol, thalach | age, exang, heartdisease)
# (sex _|_ restecg, chol, thalach | trestbps, exang, heartdisease)
# (sex _|_ restecg, chol, thalach, heartdisease | trestbps, fbs, exang)
# (sex _|_ restecg, thalach | chol, exang, heartdisease)
# (sex _|_ restecg, chol | thalach, exang, heartdisease)
# (sex _|_ restecg, chol, thalach | fbs, exang, heartdisease)
# (sex _|_ restecg, fbs, thalach, heartdisease | age, trestbps, chol)
# (sex _|_ restecg, chol, fbs, heartdisease | age, trestbps, thalach)
# (sex _|_ restecg, chol, thalach, fbs | age, trestbps, heartdisease)
# (sex _|_ restecg, chol, thalach, heartdisease | age, trestbps, fbs)
# (sex _|_ restecg, thalach | age, chol, heartdisease)
# (sex _|_ restecg, chol | age, thalach, heartdisease)
# (sex _|_ restecg, chol, thalach | age, fbs, heartdisease)
# (sex _|_ restecg, thalach | trestbps, chol, heartdisease)
# (sex _|_ restecg, thalach, heartdisease | trestbps, chol, fbs)
# (sex _|_ restecg, chol | trestbps, thalach, heartdisease)
# (sex _|_ restecg, chol, heartdisease | trestbps, fbs, thalach)
# (sex _|_ restecg, chol, thalach | trestbps, fbs, heartdisease)
# (sex _|_ restecg | chol, thalach, heartdisease)
# (sex _|_ restecg, thalach | chol, fbs, heartdisease)
# (sex _|_ restecg, chol | fbs, thalach, heartdisease)
# (sex _|_ chol, thalach, fbs, heartdisease | age, restecg, exang, trestbps)
# (sex _|_ chol, thalach | age, restecg, exang, heartdisease)
# (sex _|_ chol, thalach | restecg, exang, trestbps, heartdisease)
# (sex _|_ chol, thalach, heartdisease | restecg, fbs, exang, trestbps)
# (sex _|_ thalach | restecg, chol, exang, heartdisease)
# (sex _|_ chol | thalach, restecg, exang, heartdisease)
# (sex _|_ chol, thalach | restecg, fbs, exang, heartdisease)
# (sex _|_ fbs, thalach, heartdisease | age, restecg, chol, trestbps)
# (sex _|_ chol, fbs, heartdisease | age, restecg, thalach, trestbps)
# (sex _|_ chol, thalach, fbs | age, restecg, trestbps, heartdisease)
# (sex _|_ chol, thalach, heartdisease | age, restecg, fbs, trestbps)
# (sex _|_ thalach | age, restecg, chol, heartdisease)
# (sex _|_ chol | age, restecg, thalach, heartdisease)
# (sex _|_ chol, thalach | age, restecg, fbs, heartdisease)
# (sex _|_ thalach | restecg, chol, trestbps, heartdisease)
# (sex _|_ thalach, heartdisease | restecg, chol, fbs, trestbps)
# (sex _|_ chol | restecg, thalach, trestbps, heartdisease)
# (sex _|_ chol, heartdisease | restecg, fbs, thalach, trestbps)
# (sex _|_ chol, thalach | restecg, fbs, trestbps, heartdisease)
# (sex _|_ thalach | restecg, chol, fbs, heartdisease)
# (sex _|_ chol | restecg, fbs, thalach, heartdisease)
# (sex _|_ restecg, fbs, thalach, heartdisease | age, trestbps, chol, exang)
# (sex _|_ restecg, chol, fbs, heartdisease | age, trestbps, exang, thalach)
# (sex _|_ restecg, chol, thalach, fbs | age, trestbps, exang, heartdisease)
# (sex _|_ restecg, chol, thalach, heartdisease | age, trestbps, fbs, exang)
# (sex _|_ restecg, thalach | age, chol, exang, heartdisease)
# (sex _|_ restecg, chol | age, thalach, exang, heartdisease)
# (sex _|_ restecg, chol, thalach | age, fbs, exang, heartdisease)
# (sex _|_ restecg, thalach | trestbps, chol, exang, heartdisease)
# (sex _|_ restecg, thalach, heartdisease | trestbps, chol, exang, fbs)
# (sex _|_ restecg, chol | thalach, trestbps, exang, heartdisease)
# (sex _|_ restecg, chol, heartdisease | thalach, trestbps, fbs, exang)
# (sex _|_ restecg, chol, thalach | trestbps, fbs, exang, heartdisease)
# (sex _|_ restecg | thalach, chol, exang, heartdisease)
# (sex _|_ restecg, thalach | chol, exang, fbs, heartdisease)
# (sex _|_ restecg, chol | thalach, fbs, exang, heartdisease)
# (sex _|_ restecg, fbs, heartdisease | age, trestbps, chol, thalach)
# (sex _|_ restecg, fbs, thalach | age, trestbps, chol, heartdisease)
# (sex _|_ restecg, thalach, heartdisease | age, trestbps, chol, fbs)
# (sex _|_ restecg, chol, fbs | age, trestbps, thalach, heartdisease)
# (sex _|_ restecg, chol, heartdisease | age, trestbps, fbs, thalach)
# (sex _|_ restecg, chol, thalach | age, trestbps, fbs, heartdisease)
# (sex _|_ restecg | age, chol, thalach, heartdisease)
# (sex _|_ restecg, thalach | age, chol, fbs, heartdisease)
# (sex _|_ restecg, chol | age, fbs, thalach, heartdisease)
# (sex _|_ restecg | trestbps, chol, thalach, heartdisease)
# (sex _|_ restecg, heartdisease | trestbps, chol, thalach, fbs)
# (sex _|_ restecg, thalach | trestbps, chol, fbs, heartdisease)
# (sex _|_ restecg, chol | trestbps, fbs, thalach, heartdisease)
# (sex _|_ restecg | chol, thalach, fbs, heartdisease)
# (sex _|_ fbs, thalach, heartdisease | restecg, exang, age, trestbps, chol)
# (sex _|_ chol, fbs, heartdisease | restecg, exang, age, trestbps, thalach)
# (sex _|_ chol, thalach, fbs | restecg, exang, age, trestbps, heartdisease)
# (sex _|_ chol, thalach, heartdisease | restecg, exang, age, trestbps, fbs)
# (sex _|_ thalach | restecg, exang, age, chol, heartdisease)
# (sex _|_ chol | restecg, exang, age, thalach, heartdisease)
# (sex _|_ chol, thalach | restecg, exang, age, heartdisease, fbs)
# (sex _|_ thalach | restecg, exang, trestbps, chol, heartdisease)
# (sex _|_ thalach, heartdisease | restecg, exang, trestbps, chol, fbs)
# (sex _|_ chol | restecg, exang, trestbps, thalach, heartdisease)
# (sex _|_ chol, heartdisease | restecg, exang, trestbps, thalach, fbs)
# (sex _|_ chol, thalach | restecg, exang, trestbps, heartdisease, fbs)
# (sex _|_ thalach | restecg, exang, chol, heartdisease, fbs)
# (sex _|_ chol | restecg, exang, thalach, heartdisease, fbs)
# (sex _|_ fbs, heartdisease | restecg, age, trestbps, chol, thalach)
# (sex _|_ fbs, thalach | restecg, age, trestbps, chol, heartdisease)
# (sex _|_ thalach, heartdisease | restecg, age, trestbps, chol, fbs)
# (sex _|_ chol, fbs | restecg, age, trestbps, thalach, heartdisease)
# (sex _|_ chol, heartdisease | restecg, age, trestbps, thalach, fbs)
# (sex _|_ chol, thalach | restecg, age, trestbps, heartdisease, fbs)
# (sex _|_ thalach | restecg, age, chol, heartdisease, fbs)
# (sex _|_ chol | restecg, age, thalach, heartdisease, fbs)
# (sex _|_ heartdisease | restecg, trestbps, chol, thalach, fbs)
# (sex _|_ thalach | restecg, trestbps, chol, heartdisease, fbs)
# (sex _|_ chol | restecg, trestbps, thalach, heartdisease, fbs)
# (sex _|_ restecg, fbs, heartdisease | exang, age, trestbps, chol, thalach)
# (sex _|_ restecg, fbs, thalach | exang, age, trestbps, chol, heartdisease)
# (sex _|_ restecg, thalach, heartdisease | exang, age, trestbps, chol, fbs)
# (sex _|_ restecg, chol, fbs | exang, age, trestbps, thalach, heartdisease)
# (sex _|_ restecg, chol, heartdisease | exang, age, trestbps, thalach, fbs)
# (sex _|_ restecg, chol, thalach | exang, age, trestbps, heartdisease, fbs)
# (sex _|_ restecg | exang, age, chol, thalach, heartdisease)
# (sex _|_ restecg, thalach | exang, age, chol, heartdisease, fbs)
# (sex _|_ restecg, chol | exang, age, thalach, heartdisease, fbs)
# (sex _|_ restecg | exang, trestbps, chol, thalach, heartdisease)
# (sex _|_ restecg, heartdisease | exang, trestbps, chol, thalach, fbs)
# (sex _|_ restecg, thalach | exang, trestbps, chol, heartdisease, fbs)
# (sex _|_ restecg, chol | exang, trestbps, thalach, heartdisease, fbs)
# (sex _|_ restecg | exang, chol, thalach, heartdisease, fbs)
# (sex _|_ restecg, fbs | age, trestbps, chol, thalach, heartdisease)
# (sex _|_ restecg, heartdisease | age, trestbps, chol, thalach, fbs)
# (sex _|_ restecg, thalach | age, trestbps, chol, heartdisease, fbs)
# (sex _|_ restecg, chol | age, trestbps, thalach, heartdisease, fbs)
# (sex _|_ restecg | age, chol, thalach, heartdisease, fbs)
# (sex _|_ restecg | trestbps, chol, thalach, heartdisease, fbs)
# (sex _|_ fbs, heartdisease | restecg, exang, age, trestbps, chol, thalach)
# (sex _|_ fbs, thalach | restecg, exang, age, trestbps, chol, heartdisease)
# (sex _|_ thalach, heartdisease | restecg, exang, age, trestbps, chol, fbs)
# (sex _|_ chol, fbs | restecg, exang, age, trestbps, thalach, heartdisease)
# (sex _|_ chol, heartdisease | restecg, exang, age, trestbps, thalach, fbs)
# (sex _|_ chol, thalach | restecg, exang, age, trestbps, heartdisease, fbs)
# (sex _|_ thalach | restecg, exang, age, chol, heartdisease, fbs)
# (sex _|_ chol | restecg, exang, age, thalach, heartdisease, fbs)
# (sex _|_ heartdisease | restecg, exang, trestbps, chol, thalach, fbs)
# (sex _|_ thalach | restecg, exang, trestbps, chol, heartdisease, fbs)
# (sex _|_ chol | restecg, exang, trestbps, thalach, heartdisease, fbs)
# (sex _|_ fbs | restecg, age, trestbps, chol, thalach, heartdisease)
# (sex _|_ heartdisease | restecg, age, trestbps, chol, thalach, fbs)
# (sex _|_ thalach | restecg, age, trestbps, chol, heartdisease, fbs)
# (sex _|_ chol | restecg, age, trestbps, thalach, heartdisease, fbs)
# (sex _|_ restecg, fbs | exang, age, trestbps, chol, thalach, heartdisease)
# (sex _|_ restecg, heartdisease | exang, age, trestbps, chol, thalach, fbs)
# (sex _|_ restecg, thalach | exang, age, trestbps, chol, heartdisease, fbs)
# (sex _|_ restecg, chol | exang, age, trestbps, thalach, heartdisease, fbs)
# (sex _|_ restecg | exang, age, chol, thalach, heartdisease, fbs)
# (sex _|_ restecg | exang, trestbps, chol, thalach, heartdisease, fbs)
# (sex _|_ restecg | age, trestbps, chol, thalach, heartdisease, fbs)
# (sex _|_ fbs | restecg, exang, age, trestbps, chol, thalach, heartdisease)
# (sex _|_ heartdisease | restecg, exang, age, trestbps, chol, thalach, fbs)
# (sex _|_ thalach | restecg, exang, age, trestbps, chol, heartdisease, fbs)
# (sex _|_ chol | restecg, exang, age, trestbps, thalach, heartdisease, fbs)
# (sex _|_ restecg | exang, age, trestbps, chol, thalach, heartdisease, fbs)
# (exang _|_ age, fbs, sex)
# (exang _|_ age, fbs | sex)
# (exang _|_ fbs, sex | age)
# (exang _|_ restecg, chol, thalach | heartdisease)
# (exang _|_ age, sex | fbs)
# (exang _|_ chol, thalach | restecg, heartdisease)
# (exang _|_ fbs | age, sex)
# (exang _|_ restecg, chol, thalach | sex, heartdisease)
# (exang _|_ age | fbs, sex)
# (exang _|_ restecg, chol, thalach, heartdisease, fbs | age, trestbps)
# (exang _|_ restecg, chol, thalach | age, heartdisease)
# (exang _|_ sex | age, fbs)
# (exang _|_ restecg, chol, thalach | trestbps, heartdisease)
# (exang _|_ restecg, chol, thalach, heartdisease | trestbps, fbs)
# (exang _|_ restecg, thalach | chol, heartdisease)
# (exang _|_ restecg, chol | thalach, heartdisease)
# (exang _|_ restecg, chol, thalach | fbs, heartdisease)
# (exang _|_ chol, thalach | restecg, sex, heartdisease)
# (exang _|_ chol, thalach, fbs, heartdisease | age, restecg, trestbps)
# (exang _|_ chol, thalach | age, restecg, heartdisease)
# (exang _|_ chol, thalach | restecg, trestbps, heartdisease)
# (exang _|_ chol, thalach, heartdisease | restecg, fbs, trestbps)
# (exang _|_ thalach | restecg, chol, heartdisease)
# (exang _|_ chol | restecg, thalach, heartdisease)
# (exang _|_ chol, thalach | restecg, fbs, heartdisease)
# (exang _|_ restecg, chol, thalach, heartdisease, fbs | age, trestbps, sex)
# (exang _|_ restecg, chol, thalach | age, sex, heartdisease)
# (exang _|_ restecg, chol, thalach | trestbps, sex, heartdisease)
# (exang _|_ restecg, chol, thalach, heartdisease | trestbps, fbs, sex)
# (exang _|_ restecg, thalach | chol, sex, heartdisease)
# (exang _|_ restecg, chol | thalach, sex, heartdisease)
# (exang _|_ restecg, chol, thalach | fbs, sex, heartdisease)
# (exang _|_ restecg, fbs, thalach, heartdisease | age, trestbps, chol)
# (exang _|_ restecg, chol, fbs, heartdisease | age, trestbps, thalach)
# (exang _|_ restecg, chol, thalach, fbs | age, trestbps, heartdisease)
# (exang _|_ restecg, chol, thalach, heartdisease | age, trestbps, fbs)
# (exang _|_ restecg, thalach | age, chol, heartdisease)
# (exang _|_ restecg, chol | age, thalach, heartdisease)
# (exang _|_ restecg, chol, thalach | age, fbs, heartdisease)
# (exang _|_ restecg, thalach | trestbps, chol, heartdisease)
# (exang _|_ restecg, thalach, heartdisease | trestbps, chol, fbs)
# (exang _|_ restecg, chol | trestbps, thalach, heartdisease)
# (exang _|_ restecg, chol, heartdisease | trestbps, fbs, thalach)
# (exang _|_ restecg, chol, thalach | trestbps, fbs, heartdisease)
# (exang _|_ restecg | chol, thalach, heartdisease)
# (exang _|_ restecg, thalach | chol, fbs, heartdisease)
# (exang _|_ restecg, chol | fbs, thalach, heartdisease)
# (exang _|_ chol, thalach, fbs, heartdisease | age, restecg, sex, trestbps)
# (exang _|_ chol, thalach | age, restecg, sex, heartdisease)
# (exang _|_ chol, thalach | trestbps, restecg, sex, heartdisease)
# (exang _|_ chol, thalach, heartdisease | trestbps, restecg, fbs, sex)
# (exang _|_ thalach | restecg, chol, sex, heartdisease)
# (exang _|_ chol | restecg, thalach, sex, heartdisease)
# (exang _|_ chol, thalach | restecg, fbs, sex, heartdisease)
# (exang _|_ fbs, thalach, heartdisease | age, restecg, chol, trestbps)
# (exang _|_ chol, fbs, heartdisease | age, restecg, thalach, trestbps)
# (exang _|_ chol, thalach, fbs | age, restecg, trestbps, heartdisease)
# (exang _|_ chol, thalach, heartdisease | age, restecg, fbs, trestbps)
# (exang _|_ thalach | age, restecg, chol, heartdisease)
# (exang _|_ chol | age, restecg, thalach, heartdisease)
# (exang _|_ chol, thalach | age, restecg, fbs, heartdisease)
# (exang _|_ thalach | restecg, chol, trestbps, heartdisease)
# (exang _|_ thalach, heartdisease | restecg, chol, fbs, trestbps)
# (exang _|_ chol | restecg, thalach, trestbps, heartdisease)
# (exang _|_ chol, heartdisease | restecg, fbs, thalach, trestbps)
# (exang _|_ chol, thalach | restecg, fbs, trestbps, heartdisease)
# (exang _|_ thalach | restecg, chol, fbs, heartdisease)
# (exang _|_ chol | restecg, fbs, thalach, heartdisease)
# (exang _|_ restecg, fbs, thalach, heartdisease | age, trestbps, chol, sex)
# (exang _|_ restecg, chol, fbs, heartdisease | age, trestbps, thalach, sex)
# (exang _|_ restecg, chol, thalach, fbs | age, trestbps, sex, heartdisease)
# (exang _|_ restecg, chol, thalach, heartdisease | age, trestbps, fbs, sex)
# (exang _|_ restecg, thalach | age, chol, sex, heartdisease)
# (exang _|_ restecg, chol | age, thalach, sex, heartdisease)
# (exang _|_ restecg, chol, thalach | age, fbs, sex, heartdisease)
# (exang _|_ restecg, thalach | trestbps, chol, sex, heartdisease)
# (exang _|_ restecg, thalach, heartdisease | trestbps, chol, fbs, sex)
# (exang _|_ restecg, chol | trestbps, thalach, sex, heartdisease)
# (exang _|_ restecg, chol, heartdisease | trestbps, fbs, thalach, sex)
# (exang _|_ restecg, chol, thalach | trestbps, fbs, sex, heartdisease)
# (exang _|_ restecg | chol, thalach, sex, heartdisease)
# (exang _|_ restecg, thalach | chol, fbs, sex, heartdisease)
# (exang _|_ restecg, chol | fbs, thalach, sex, heartdisease)
# (exang _|_ restecg, fbs, heartdisease | age, trestbps, chol, thalach)
# (exang _|_ restecg, fbs, thalach | age, trestbps, chol, heartdisease)
# (exang _|_ restecg, thalach, heartdisease | age, trestbps, chol, fbs)
# (exang _|_ restecg, chol, fbs | age, trestbps, thalach, heartdisease)
# (exang _|_ restecg, chol, heartdisease | age, trestbps, fbs, thalach)
# (exang _|_ restecg, chol, thalach | age, trestbps, fbs, heartdisease)
# (exang _|_ restecg | age, chol, thalach, heartdisease)
# (exang _|_ restecg, thalach | age, chol, fbs, heartdisease)
# (exang _|_ restecg, chol | age, fbs, thalach, heartdisease)
# (exang _|_ restecg | trestbps, chol, thalach, heartdisease)
# (exang _|_ restecg, heartdisease | trestbps, chol, thalach, fbs)
# (exang _|_ restecg, thalach | trestbps, chol, fbs, heartdisease)
# (exang _|_ restecg, chol | trestbps, fbs, thalach, heartdisease)
# (exang _|_ restecg | chol, thalach, fbs, heartdisease)
# (exang _|_ fbs, thalach, heartdisease | restecg, sex, age, trestbps, chol)
# (exang _|_ chol, fbs, heartdisease | restecg, sex, age, trestbps, thalach)
# (exang _|_ chol, thalach, fbs | restecg, sex, age, trestbps, heartdisease)
# (exang _|_ chol, thalach, heartdisease | restecg, sex, age, trestbps, fbs)
# (exang _|_ thalach | restecg, sex, age, chol, heartdisease)
# (exang _|_ chol | restecg, sex, age, thalach, heartdisease)
# (exang _|_ chol, thalach | restecg, sex, age, heartdisease, fbs)
# (exang _|_ thalach | restecg, sex, trestbps, chol, heartdisease)
# (exang _|_ thalach, heartdisease | restecg, sex, trestbps, chol, fbs)
# (exang _|_ chol | restecg, sex, trestbps, thalach, heartdisease)
# (exang _|_ chol, heartdisease | restecg, sex, trestbps, thalach, fbs)
# (exang _|_ chol, thalach | restecg, sex, trestbps, heartdisease, fbs)
# (exang _|_ thalach | restecg, sex, chol, heartdisease, fbs)
# (exang _|_ chol | restecg, sex, thalach, heartdisease, fbs)
# (exang _|_ fbs, heartdisease | restecg, age, trestbps, chol, thalach)
# (exang _|_ fbs, thalach | restecg, age, trestbps, chol, heartdisease)
# (exang _|_ thalach, heartdisease | restecg, age, trestbps, chol, fbs)
# (exang _|_ chol, fbs | restecg, age, trestbps, thalach, heartdisease)
# (exang _|_ chol, heartdisease | restecg, age, trestbps, thalach, fbs)
# (exang _|_ chol, thalach | restecg, age, trestbps, heartdisease, fbs)
# (exang _|_ thalach | restecg, age, chol, heartdisease, fbs)
# (exang _|_ chol | restecg, age, thalach, heartdisease, fbs)
# (exang _|_ heartdisease | restecg, trestbps, chol, thalach, fbs)
# (exang _|_ thalach | restecg, trestbps, chol, heartdisease, fbs)
# (exang _|_ chol | restecg, trestbps, thalach, heartdisease, fbs)
# (exang _|_ restecg, fbs, heartdisease | sex, age, trestbps, chol, thalach)
# (exang _|_ restecg, fbs, thalach | sex, age, trestbps, chol, heartdisease)
# (exang _|_ restecg, thalach, heartdisease | sex, age, trestbps, chol, fbs)
# (exang _|_ restecg, chol, fbs | sex, age, trestbps, thalach, heartdisease)
# (exang _|_ restecg, chol, heartdisease | sex, age, trestbps, thalach, fbs)
# (exang _|_ restecg, chol, thalach | sex, age, trestbps, heartdisease, fbs)
# (exang _|_ restecg | sex, age, chol, thalach, heartdisease)
# (exang _|_ restecg, thalach | sex, age, chol, heartdisease, fbs)
# (exang _|_ restecg, chol | sex, age, thalach, heartdisease, fbs)
# (exang _|_ restecg | sex, trestbps, chol, thalach, heartdisease)
# (exang _|_ restecg, heartdisease | sex, trestbps, chol, thalach, fbs)
# (exang _|_ restecg, thalach | sex, trestbps, chol, heartdisease, fbs)
# (exang _|_ restecg, chol | sex, trestbps, thalach, heartdisease, fbs)
# (exang _|_ restecg | sex, chol, thalach, heartdisease, fbs)
# (exang _|_ restecg, fbs | age, trestbps, chol, thalach, heartdisease)
# (exang _|_ restecg, heartdisease | age, trestbps, chol, thalach, fbs)
# (exang _|_ restecg, thalach | age, trestbps, chol, heartdisease, fbs)
# (exang _|_ restecg, chol | age, trestbps, thalach, heartdisease, fbs)
# (exang _|_ restecg | age, chol, thalach, heartdisease, fbs)
# (exang _|_ restecg | trestbps, chol, thalach, heartdisease, fbs)
# (exang _|_ fbs, heartdisease | restecg, sex, age, trestbps, chol, thalach)
# (exang _|_ fbs, thalach | restecg, sex, age, trestbps, chol, heartdisease)
# (exang _|_ thalach, heartdisease | restecg, sex, age, trestbps, chol, fbs)
# (exang _|_ chol, fbs | restecg, sex, age, trestbps, thalach, heartdisease)
# (exang _|_ chol, heartdisease | restecg, sex, age, trestbps, thalach, fbs)
# (exang _|_ chol, thalach | restecg, sex, age, trestbps, heartdisease, fbs)
# (exang _|_ thalach | restecg, sex, age, chol, heartdisease, fbs)
# (exang _|_ chol | restecg, sex, age, thalach, heartdisease, fbs)
# (exang _|_ heartdisease | restecg, sex, trestbps, chol, thalach, fbs)
# (exang _|_ thalach | restecg, sex, trestbps, chol, heartdisease, fbs)
# (exang _|_ chol | restecg, sex, trestbps, thalach, heartdisease, fbs)
# (exang _|_ fbs | restecg, age, trestbps, chol, thalach, heartdisease)
# (exang _|_ heartdisease | restecg, age, trestbps, chol, thalach, fbs)
# (exang _|_ thalach | restecg, age, trestbps, chol, heartdisease, fbs)
# (exang _|_ chol | restecg, age, trestbps, thalach, heartdisease, fbs)
# (exang _|_ restecg, fbs | sex, age, trestbps, chol, thalach, heartdisease)
# (exang _|_ restecg, heartdisease | sex, age, trestbps, chol, thalach, fbs)
# (exang _|_ restecg, thalach | sex, age, trestbps, chol, heartdisease, fbs)
# (exang _|_ restecg, chol | sex, age, trestbps, thalach, heartdisease, fbs)
# (exang _|_ restecg | sex, age, chol, thalach, heartdisease, fbs)
# (exang _|_ restecg | sex, trestbps, chol, thalach, heartdisease, fbs)
# (exang _|_ restecg | age, trestbps, chol, thalach, heartdisease, fbs)
# (exang _|_ fbs | restecg, sex, age, trestbps, chol, thalach, heartdisease)
# (exang _|_ heartdisease | restecg, sex, age, trestbps, chol, thalach, fbs)
# (exang _|_ thalach | restecg, sex, age, trestbps, chol, heartdisease, fbs)
# (exang _|_ chol | restecg, sex, age, trestbps, thalach, heartdisease, fbs)
# (exang _|_ restecg | sex, age, trestbps, chol, thalach, heartdisease, fbs)
# (heartdisease _|_ exang, sex | age, trestbps)
# (heartdisease _|_ age, exang, sex | trestbps, fbs)
# (heartdisease _|_ exang, sex | age, restecg, trestbps)
# (heartdisease _|_ age, exang, sex | restecg, fbs, trestbps)
# (heartdisease _|_ exang | age, trestbps, sex)
# (heartdisease _|_ age, exang | trestbps, fbs, sex)
# (heartdisease _|_ sex | age, trestbps, exang)
# (heartdisease _|_ age, sex | trestbps, fbs, exang)
# (heartdisease _|_ exang, sex | age, trestbps, chol)
# (heartdisease _|_ exang, sex | age, trestbps, thalach)
# (heartdisease _|_ exang, sex | age, trestbps, fbs)
# (heartdisease _|_ age, exang, sex | trestbps, chol, fbs)
# (heartdisease _|_ age, exang, sex | trestbps, fbs, thalach)
# (heartdisease _|_ exang | age, restecg, sex, trestbps)
# (heartdisease _|_ age, exang | trestbps, restecg, fbs, sex)
# (heartdisease _|_ sex | age, restecg, exang, trestbps)
# (heartdisease _|_ age, sex | restecg, fbs, exang, trestbps)
# (heartdisease _|_ exang, sex | age, restecg, chol, trestbps)
# (heartdisease _|_ exang, sex | age, restecg, thalach, trestbps)
# (heartdisease _|_ exang, sex | age, restecg, fbs, trestbps)
# (heartdisease _|_ age, exang, sex | restecg, chol, fbs, trestbps)
# (heartdisease _|_ age, exang, sex | restecg, fbs, thalach, trestbps)
# (heartdisease _|_ age | trestbps, fbs, exang, sex)
# (heartdisease _|_ exang | age, trestbps, chol, sex)
# ...
# (thalach _|_ sex | restecg, exang, age, trestbps, fbs)
# (thalach _|_ trestbps, fbs, sex | restecg, exang, age, chol, heartdisease)
# (thalach _|_ trestbps, chol, sex | restecg, exang, age, heartdisease, fbs)
# (thalach _|_ age, fbs, sex | restecg, exang, trestbps, chol, heartdisease)
# (thalach _|_ age, sex | restecg, exang, trestbps, chol, fbs)
# (thalach _|_ age, chol, sex | restecg, exang, trestbps, heartdisease, fbs)
# (thalach _|_ age, trestbps, sex | restecg, exang, chol, heartdisease, fbs)
# (thalach _|_ fbs, exang, sex | restecg, age, trestbps, chol, heartdisease)
# (thalach _|_ exang, sex | restecg, age, trestbps, chol, fbs)
# (thalach _|_ chol, exang, sex | restecg, age, trestbps, heartdisease, fbs)
# (thalach _|_ trestbps, exang, sex | restecg, age, chol, heartdisease, fbs)
# (thalach _|_ age, exang, sex | restecg, trestbps, chol, heartdisease, fbs)
# (thalach _|_ restecg, chol, fbs | sex, exang, age, trestbps, heartdisease)
# (thalach _|_ restecg, fbs, trestbps | sex, exang, age, chol, heartdisease)
# (thalach _|_ restecg, chol, trestbps | sex, exang, age, heartdisease, fbs)
# (thalach _|_ age, restecg, fbs | sex, exang, trestbps, chol, heartdisease)
# (thalach _|_ age | sex, exang, trestbps, chol, fbs)
# (thalach _|_ age, restecg, chol | sex, exang, trestbps, heartdisease, fbs)
# (thalach _|_ age, restecg, trestbps | sex, exang, chol, heartdisease, fbs)
# (thalach _|_ restecg, fbs, exang | sex, age, trestbps, chol, heartdisease)
# (thalach _|_ exang | sex, age, trestbps, chol, fbs)
# (thalach _|_ restecg, chol, exang | sex, age, trestbps, heartdisease, fbs)
# (thalach _|_ restecg, exang, trestbps | sex, age, chol, heartdisease, fbs)
# (thalach _|_ age, restecg, exang | sex, trestbps, chol, heartdisease, fbs)
# (thalach _|_ restecg, fbs, sex | exang, age, trestbps, chol, heartdisease)
# (thalach _|_ sex | exang, age, trestbps, chol, fbs)
# (thalach _|_ restecg, chol, sex | exang, age, trestbps, heartdisease, fbs)
# (thalach _|_ trestbps, restecg, sex | exang, age, chol, heartdisease, fbs)
# (thalach _|_ age, restecg, sex | exang, trestbps, chol, heartdisease, fbs)
# (thalach _|_ restecg, exang, sex | age, trestbps, chol, heartdisease, fbs)
# (thalach _|_ chol, fbs | restecg, sex, exang, age, trestbps, heartdisease)
# (thalach _|_ trestbps, fbs | restecg, sex, exang, age, chol, heartdisease)
# (thalach _|_ trestbps, chol | restecg, sex, exang, age, heartdisease, fbs)
# (thalach _|_ age, fbs | restecg, sex, exang, trestbps, chol, heartdisease)
# (thalach _|_ age | restecg, sex, exang, trestbps, chol, fbs)
# (thalach _|_ age, chol | restecg, sex, exang, trestbps, heartdisease, fbs)
# (thalach _|_ age, trestbps | restecg, sex, exang, chol, heartdisease, fbs)
# (thalach _|_ fbs, exang | restecg, sex, age, trestbps, chol, heartdisease)
# (thalach _|_ exang | restecg, sex, age, trestbps, chol, fbs)
# (thalach _|_ chol, exang | restecg, sex, age, trestbps, heartdisease, fbs)
# (thalach _|_ trestbps, exang | restecg, sex, age, chol, heartdisease, fbs)
# (thalach _|_ age, exang | restecg, sex, trestbps, chol, heartdisease, fbs)
# (thalach _|_ fbs, sex | restecg, exang, age, trestbps, chol, heartdisease)
# (thalach _|_ sex | restecg, exang, age, trestbps, chol, fbs)
# (thalach _|_ chol, sex | restecg, exang, age, trestbps, heartdisease, fbs)
# (thalach _|_ trestbps, sex | restecg, exang, age, chol, heartdisease, fbs)
# (thalach _|_ age, sex | restecg, exang, trestbps, chol, heartdisease, fbs)
# (thalach _|_ exang, sex | restecg, age, trestbps, chol, heartdisease, fbs)
# (thalach _|_ restecg, fbs | sex, exang, age, trestbps, chol, heartdisease)
# (thalach _|_ restecg, chol | sex, exang, age, trestbps, heartdisease, fbs)
# (thalach _|_ restecg, trestbps | sex, exang, age, chol, heartdisease, fbs)
# (thalach _|_ age, restecg | sex, exang, trestbps, chol, heartdisease, fbs)
# (thalach _|_ restecg, exang | sex, age, trestbps, chol, heartdisease, fbs)
# (thalach _|_ restecg, sex | exang, age, trestbps, chol, heartdisease, fbs)
# (thalach _|_ fbs | restecg, sex, exang, age, trestbps, chol, heartdisease)
# (thalach _|_ chol | restecg, sex, exang, age, trestbps, heartdisease, fbs)
# (thalach _|_ trestbps | restecg, sex, exang, age, chol, heartdisease, fbs)
# (thalach _|_ age | restecg, sex, exang, trestbps, chol, heartdisease, fbs)
# (thalach _|_ exang | restecg, sex, age, trestbps, chol, heartdisease, fbs)
# (thalach _|_ sex | restecg, exang, age, trestbps, chol, heartdisease, fbs)
# (thalach _|_ restecg | sex, exang, age, trestbps, chol, heartdisease, fbs)
# (chol _|_ age, restecg, trestbps, thalach, sex, fbs, exang | heartdisease)
# (chol _|_ age, trestbps, thalach, sex, fbs, exang | restecg, heartdisease)
# (chol _|_ age, restecg, trestbps, thalach, fbs, exang | sex, heartdisease)
# (chol _|_ age, restecg, trestbps, thalach, sex, fbs | exang, heartdisease)
# (chol _|_ exang, sex | age, trestbps)
# (chol _|_ restecg, trestbps, thalach, sex, fbs, exang | age, heartdisease)
# (chol _|_ age, restecg, thalach, sex, fbs, exang | trestbps, heartdisease)
# (chol _|_ age, exang, sex | trestbps, fbs)
# (chol _|_ age, restecg, trestbps, sex, fbs, exang | thalach, heartdisease)
# (chol _|_ age, restecg, trestbps, thalach, sex, exang | fbs, heartdisease)
# (chol _|_ age, trestbps, thalach, fbs, exang | restecg, sex, heartdisease)
# (chol _|_ age, trestbps, thalach, sex, fbs | restecg, exang, heartdisease)
# (chol _|_ exang, sex | age, restecg, trestbps)
# (chol _|_ trestbps, thalach, sex, fbs, exang | age, restecg, heartdisease)
# (chol _|_ age, thalach, sex, fbs, exang | restecg, trestbps, heartdisease)
# (chol _|_ age, exang, sex | restecg, fbs, trestbps)
# (chol _|_ age, trestbps, sex, fbs, exang | restecg, thalach, heartdisease)
# (chol _|_ age, trestbps, thalach, sex, exang | restecg, fbs, heartdisease)
# (chol _|_ age, restecg, trestbps, thalach, fbs | exang, sex, heartdisease)
# (chol _|_ exang | age, trestbps, sex)
# (chol _|_ restecg, trestbps, thalach, fbs, exang | age, sex, heartdisease)
# (chol _|_ age, restecg, thalach, fbs, exang | trestbps, sex, heartdisease)
# (chol _|_ age, exang | trestbps, fbs, sex)
# (chol _|_ age, restecg, trestbps, fbs, exang | thalach, sex, heartdisease)
# (chol _|_ age, restecg, trestbps, thalach, exang | fbs, sex, heartdisease)
# (chol _|_ sex | age, trestbps, exang)
# (chol _|_ restecg, trestbps, thalach, sex, fbs | age, exang, heartdisease)
# (chol _|_ age, restecg, thalach, sex, fbs | trestbps, exang, heartdisease)
# (chol _|_ age, sex | trestbps, fbs, exang)
# (chol _|_ age, restecg, trestbps, sex, fbs | thalach, exang, heartdisease)
# (chol _|_ age, restecg, trestbps, thalach, sex | fbs, exang, heartdisease)
# (chol _|_ exang, sex | age, trestbps, thalach)
# (chol _|_ restecg, thalach, sex, fbs, exang | age, trestbps, heartdisease)
# (chol _|_ exang, sex | age, trestbps, fbs)
# (chol _|_ restecg, trestbps, sex, fbs, exang | age, thalach, heartdisease)
# (chol _|_ restecg, trestbps, thalach, sex, exang | age, fbs, heartdisease)
# (chol _|_ age, restecg, sex, fbs, exang | trestbps, thalach, heartdisease)
# (chol _|_ age, exang, sex | trestbps, fbs, thalach)
# (chol _|_ age, restecg, thalach, sex, exang | trestbps, fbs, heartdisease)
# (chol _|_ age, restecg, trestbps, sex, exang | fbs, thalach, heartdisease)
# (chol _|_ age, trestbps, fbs, thalach | restecg, exang, sex, heartdisease)
# (chol _|_ exang | age, restecg, sex, trestbps)
# (chol _|_ trestbps, fbs, thalach, exang | age, restecg, sex, heartdisease)
# (chol _|_ age, fbs, thalach, exang | trestbps, restecg, sex, heartdisease)
# (chol _|_ age, exang | trestbps, restecg, fbs, sex)
# (chol _|_ age, trestbps, fbs, exang | restecg, thalach, sex, heartdisease)
# (chol _|_ age, trestbps, exang, thalach | restecg, fbs, sex, heartdisease)
# (chol _|_ sex | age, restecg, exang, trestbps)
# (chol _|_ trestbps, fbs, thalach, sex | age, restecg, exang, heartdisease)
# (chol _|_ age, fbs, thalach, sex | restecg, exang, trestbps, heartdisease)
# (chol _|_ age, sex | restecg, fbs, exang, trestbps)
# (chol _|_ age, trestbps, fbs, sex | thalach, restecg, exang, heartdisease)
# (chol _|_ age, trestbps, thalach, sex | restecg, fbs, exang, heartdisease)
# (chol _|_ exang, sex | age, restecg, thalach, trestbps)
# (chol _|_ fbs, thalach, exang, sex | age, restecg, trestbps, heartdisease)
# (chol _|_ exang, sex | age, restecg, fbs, trestbps)
# (chol _|_ trestbps, fbs, exang, sex | age, restecg, thalach, heartdisease)
# (chol _|_ trestbps, exang, thalach, sex | age, restecg, fbs, heartdisease)
# (chol _|_ age, fbs, exang, sex | restecg, thalach, trestbps, heartdisease)
# (chol _|_ age, exang, sex | restecg, fbs, thalach, trestbps)
# (chol _|_ age, exang, thalach, sex | restecg, fbs, trestbps, heartdisease)
# (chol _|_ age, trestbps, exang, sex | restecg, fbs, thalach, heartdisease)
# (chol _|_ restecg, fbs, thalach, trestbps | age, exang, sex, heartdisease)
# (chol _|_ age, restecg, fbs, thalach | trestbps, exang, sex, heartdisease)
# (chol _|_ age | trestbps, fbs, exang, sex)
# (chol _|_ age, restecg, fbs, trestbps | thalach, exang, sex, heartdisease)
# (chol _|_ age, restecg, thalach, trestbps | fbs, exang, sex, heartdisease)
# (chol _|_ exang | age, trestbps, thalach, sex)
# (chol _|_ restecg, fbs, thalach, exang | age, trestbps, sex, heartdisease)
# (chol _|_ exang | age, trestbps, fbs, sex)
# (chol _|_ restecg, fbs, exang, trestbps | age, thalach, sex, heartdisease)
# (chol _|_ restecg, exang, thalach, trestbps | age, fbs, sex, heartdisease)
# (chol _|_ age, restecg, fbs, exang | trestbps, thalach, sex, heartdisease)
# (chol _|_ age, exang | trestbps, fbs, thalach, sex)
# (chol _|_ age, restecg, exang, thalach | trestbps, fbs, sex, heartdisease)
# (chol _|_ age, restecg, exang, trestbps | fbs, thalach, sex, heartdisease)
# (chol _|_ sex | age, trestbps, exang, thalach)
# (chol _|_ restecg, fbs, thalach, sex | age, trestbps, exang, heartdisease)
# (chol _|_ sex | age, trestbps, fbs, exang)
# (chol _|_ trestbps, fbs, restecg, sex | age, thalach, exang, heartdisease)
# (chol _|_ trestbps, thalach, restecg, sex | age, fbs, exang, heartdisease)
# (chol _|_ age, restecg, fbs, sex | thalach, trestbps, exang, heartdisease)
# (chol _|_ age, sex | thalach, trestbps, fbs, exang)
# (chol _|_ age, restecg, thalach, sex | trestbps, fbs, exang, heartdisease)
# (chol _|_ age, restecg, sex, trestbps | thalach, fbs, exang, heartdisease)
# (chol _|_ restecg, fbs, exang, sex | age, trestbps, thalach, heartdisease)
# (chol _|_ exang, sex | age, trestbps, fbs, thalach)
# (chol _|_ restecg, exang, thalach, sex | age, trestbps, fbs, heartdisease)
# (chol _|_ trestbps, exang, restecg, sex | age, fbs, thalach, heartdisease)
# (chol _|_ age, restecg, exang, sex | trestbps, fbs, thalach, heartdisease)
# (chol _|_ trestbps, fbs, thalach | restecg, sex, exang, age, heartdisease)
# (chol _|_ age, fbs, thalach | restecg, sex, exang, trestbps, heartdisease)
# (chol _|_ age | restecg, sex, exang, trestbps, fbs)
# (chol _|_ age, trestbps, fbs | restecg, sex, exang, thalach, heartdisease)
# (chol _|_ age, trestbps, thalach | restecg, sex, exang, heartdisease, fbs)
# (chol _|_ exang | restecg, sex, age, trestbps, thalach)
# (chol _|_ fbs, thalach, exang | restecg, sex, age, trestbps, heartdisease)
# (chol _|_ exang | restecg, sex, age, trestbps, fbs)
# (chol _|_ trestbps, fbs, exang | restecg, sex, age, thalach, heartdisease)
# (chol _|_ trestbps, exang, thalach | restecg, sex, age, heartdisease, fbs)
# (chol _|_ age, fbs, exang | restecg, sex, trestbps, thalach, heartdisease)
# (chol _|_ age, exang | restecg, sex, trestbps, thalach, fbs)
# (chol _|_ age, exang, thalach | restecg, sex, trestbps, heartdisease, fbs)
# (chol _|_ age, trestbps, exang | restecg, sex, thalach, heartdisease, fbs)
# (chol _|_ sex | restecg, exang, age, trestbps, thalach)
# (chol _|_ fbs, thalach, sex | restecg, exang, age, trestbps, heartdisease)
# (chol _|_ sex | restecg, exang, age, trestbps, fbs)
# (chol _|_ trestbps, fbs, sex | restecg, exang, age, thalach, heartdisease)
# (chol _|_ trestbps, thalach, sex | restecg, exang, age, heartdisease, fbs)
# (chol _|_ age, fbs, sex | restecg, exang, trestbps, thalach, heartdisease)
# (chol _|_ age, sex | restecg, exang, trestbps, thalach, fbs)
# (chol _|_ age, thalach, sex | restecg, exang, trestbps, heartdisease, fbs)
# (chol _|_ age, trestbps, sex | restecg, exang, thalach, heartdisease, fbs)
# (chol _|_ fbs, exang, sex | restecg, age, trestbps, thalach, heartdisease)
# (chol _|_ exang, sex | restecg, age, trestbps, thalach, fbs)
# (chol _|_ exang, thalach, sex | restecg, age, trestbps, heartdisease, fbs)
# (chol _|_ trestbps, exang, sex | restecg, age, thalach, heartdisease, fbs)
# (chol _|_ age, exang, sex | restecg, trestbps, thalach, heartdisease, fbs)
# (chol _|_ restecg, fbs, thalach | sex, exang, age, trestbps, heartdisease)
# (chol _|_ restecg, fbs, trestbps | sex, exang, age, thalach, heartdisease)
# (chol _|_ restecg, thalach, trestbps | sex, exang, age, heartdisease, fbs)
# (chol _|_ age, restecg, fbs | sex, exang, trestbps, thalach, heartdisease)
# (chol _|_ age | sex, exang, trestbps, thalach, fbs)
# (chol _|_ age, restecg, thalach | sex, exang, trestbps, heartdisease, fbs)
# (chol _|_ age, restecg, trestbps | sex, exang, thalach, heartdisease, fbs)
# (chol _|_ restecg, fbs, exang | sex, age, trestbps, thalach, heartdisease)
# (chol _|_ exang | sex, age, trestbps, thalach, fbs)
# (chol _|_ restecg, exang, thalach | sex, age, trestbps, heartdisease, fbs)
# (chol _|_ restecg, exang, trestbps | sex, age, thalach, heartdisease, fbs)
# (chol _|_ age, restecg, exang | sex, trestbps, thalach, heartdisease, fbs)
# (chol _|_ restecg, fbs, sex | exang, age, trestbps, thalach, heartdisease)
# (chol _|_ sex | exang, age, trestbps, thalach, fbs)
# (chol _|_ restecg, thalach, sex | exang, age, trestbps, heartdisease, fbs)
# (chol _|_ trestbps, restecg, sex | exang, age, thalach, heartdisease, fbs)
# (chol _|_ age, restecg, sex | exang, trestbps, thalach, heartdisease, fbs)
# (chol _|_ restecg, exang, sex | age, trestbps, thalach, heartdisease, fbs)
# (chol _|_ fbs, thalach | restecg, sex, exang, age, trestbps, heartdisease)
# (chol _|_ trestbps, fbs | restecg, sex, exang, age, thalach, heartdisease)
# (chol _|_ trestbps, thalach | restecg, sex, exang, age, heartdisease, fbs)
# (chol _|_ age, fbs | restecg, sex, exang, trestbps, thalach, heartdisease)
# (chol _|_ age | restecg, sex, exang, trestbps, thalach, fbs)
# (chol _|_ age, thalach | restecg, sex, exang, trestbps, heartdisease, fbs)
# (chol _|_ age, trestbps | restecg, sex, exang, thalach, heartdisease, fbs)
# (chol _|_ fbs, exang | restecg, sex, age, trestbps, thalach, heartdisease)
# (chol _|_ exang | restecg, sex, age, trestbps, thalach, fbs)
# (chol _|_ exang, thalach | restecg, sex, age, trestbps, heartdisease, fbs)
# (chol _|_ trestbps, exang | restecg, sex, age, thalach, heartdisease, fbs)
# (chol _|_ age, exang | restecg, sex, trestbps, thalach, heartdisease, fbs)
# (chol _|_ fbs, sex | restecg, exang, age, trestbps, thalach, heartdisease)
# (chol _|_ sex | restecg, exang, age, trestbps, thalach, fbs)
# (chol _|_ thalach, sex | restecg, exang, age, trestbps, heartdisease, fbs)
# (chol _|_ trestbps, sex | restecg, exang, age, thalach, heartdisease, fbs)
# (chol _|_ age, sex | restecg, exang, trestbps, thalach, heartdisease, fbs)
# (chol _|_ exang, sex | restecg, age, trestbps, thalach, heartdisease, fbs)
# (chol _|_ restecg, fbs | sex, exang, age, trestbps, thalach, heartdisease)
# (chol _|_ restecg, thalach | sex, exang, age, trestbps, heartdisease, fbs)
# (chol _|_ restecg, trestbps | sex, exang, age, thalach, heartdisease, fbs)
# (chol _|_ age, restecg | sex, exang, trestbps, thalach, heartdisease, fbs)
# (chol _|_ restecg, exang | sex, age, trestbps, thalach, heartdisease, fbs)
# (chol _|_ restecg, sex | exang, age, trestbps, thalach, heartdisease, fbs)
# (chol _|_ fbs | restecg, sex, exang, age, trestbps, thalach, heartdisease)
# (chol _|_ thalach | restecg, sex, exang, age, trestbps, heartdisease, fbs)
# (chol _|_ trestbps | restecg, sex, exang, age, thalach, heartdisease, fbs)
# (chol _|_ age | restecg, sex, exang, trestbps, thalach, heartdisease, fbs)
# (chol _|_ exang | restecg, sex, age, trestbps, thalach, heartdisease, fbs)
# (chol _|_ sex | restecg, exang, age, trestbps, thalach, heartdisease, fbs)
# (chol _|_ restecg | sex, exang, age, trestbps, thalach, heartdisease, fbs)

# %%
from pgmpy.inference import VariableElimination
heartDisease_infer = VariableElimination(model)
q = heartDisease_infer.query(variables=["heartdisease"],
evidence={"age": 29})

print(q)
# Out:
# Finding Elimination Order: : 100%|██████████| 7/7 [00:00<00:00, 448.09it/s]
# Eliminating: exang: 100%|██████████| 7/7 [00:00<00:00, 366.63it/s]
# +-----------------+---------------------+
# | heartdisease    |   phi(heartdisease) |
# +=================+=====================+
# | heartdisease(0) |              0.6630 |
# +-----------------+---------------------+
# | heartdisease(1) |              0.3370 |
# +-----------------+---------------------+

# %%
q = heartDisease_infer.query(variables=["heartdisease"],
evidence={"chol": 100})

print(q)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\pgmpy\factors\discrete\DiscreteFactor.py:438: UserWarning: Found unknown state name. Trying to switch to using all state names as state numbers
#   warn(
# Finding Elimination Order: : 100%|██████████| 7/7 [00:00<?, ?it/s]
# Eliminating: exang: 100%|██████████| 7/7 [00:00<00:00, 90.35it/s]
# +-----------------+---------------------+
# | heartdisease    |   phi(heartdisease) |
# +=================+=====================+
# | heartdisease(0) |              1.0000 |
# +-----------------+---------------------+
# | heartdisease(1) |              0.0000 |
# +-----------------+---------------------+
