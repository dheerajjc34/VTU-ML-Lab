# %% [markdown]
# # Dheeraj J C - 1CR17CS036 (Prog 7)
#
# Write a program to construct a Bayesian network considering medical data. Use this model to demonstrate the diagnosis of heart patients using standard Heart Disease Data Set. You can use Java/Python ML library classes/API.

# %%
import numpy as np
from urllib.request import urlopen
import urllib
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as skl
import pandas as pd

# %%
#data= "http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.hungarian.data"

# %%
names = ["age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal", "heartdisease"]

# %%
# for local data
data=pd.read_csv("heartdisease.csv", names=names)
heartDisease=pd.DataFrame(data)
#heartDisease = pd.read_csv(urlopen(data), names=names)
heartDisease.head()
# Out:
#    age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 0   28    1   2      130  132   0       2     185     0      0.0     ?  ?
# 1   29    1   2      120  243   0       0     160     0      0.0     ?  ?
# 2   29    1   2      140    ?   0       0     170     0      0.0     ?  ?
# 3   30    0   1      170  237   0       1     170     0      0.0     ?  ?
# 4   31    0   2      100  219   0       1     150     0      0.0     ?  ?
#
#   thal  heartdisease
# 0    ?             0
# 1    ?             0
# 2    ?             0
# 3    6             0
# 4    ?             0

# %%
del heartDisease["ca"]
del heartDisease["slope"]
del heartDisease["thal"]
del heartDisease["oldpeak"]

# %%
heartDisease = heartDisease.replace("?", np.nan)
heartDisease.dtypes
# Out:
# age              int64
# sex              int64
# cp               int64
# trestbps        object
# chol            object
# fbs             object
# restecg         object
# thalach         object
# exang           object
# heartdisease     int64
# dtype: object

# %%
heartDisease.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'heartdisease'],
#       dtype='object')

# %%
from pgmpy.models import BayesianModel
from pgmpy.estimators import MaximumLikelihoodEstimator, BayesianEstimator

# %%
model = BayesianModel([("age", "trestbps"),("age", "fbs"),("sex", "trestbps"),("sex", "trestbps"),("exang", "trestbps"),("trestbps", "heartdisease"),("fbs", "heartdisease"),("heartdisease", "restecg"),("heartdisease", "thalach"),("heartdisease", "thalach"),("heartdisease", "chol")])

# %%
model.fit(heartDisease, estimator=MaximumLikelihoodEstimator)
print(model.get_cpds("age"))
# Out:
# +---------+------------+
# | age(28) | 0.00383142 |
# +---------+------------+
# | age(29) | 0.00383142 |
# +---------+------------+
# | age(30) | 0.00383142 |
# +---------+------------+
# | age(31) | 0.00766284 |
# +---------+------------+
# | age(32) | 0.0153257  |
# +---------+------------+
# | age(33) | 0.00766284 |
# +---------+------------+
# | age(34) | 0.0153257  |
# +---------+------------+
# | age(35) | 0.0191571  |
# +---------+------------+
# | age(36) | 0.0191571  |
# +---------+------------+
# | age(37) | 0.0306513  |
# +---------+------------+
# | age(38) | 0.0191571  |
# +---------+------------+
# | age(39) | 0.0344828  |
# +---------+------------+
# | age(40) | 0.0191571  |
# +---------+------------+
# | age(41) | 0.0383142  |
# +---------+------------+
# | age(42) | 0.0268199  |
# +---------+------------+
# | age(43) | 0.0421456  |
# +---------+------------+
# | age(44) | 0.0268199  |
# +---------+------------+
# | age(45) | 0.0229885  |
# +---------+------------+
# | age(46) | 0.045977   |
# +---------+------------+
# | age(47) | 0.0344828  |
# +---------+------------+
# | age(48) | 0.0613027  |
# +---------+------------+
# | age(49) | 0.0421456  |
# +---------+------------+
# | age(50) | 0.045977   |
# +---------+------------+
# | age(51) | 0.0344828  |
# +---------+------------+
# | age(52) | 0.0574713  |
# +---------+------------+
# | age(53) | 0.0383142  |
# +---------+------------+
# | age(54) | 0.0842912  |
# +---------+------------+
# | age(55) | 0.0536398  |
# +---------+------------+
# | age(56) | 0.0306513  |
# +---------+------------+
# | age(57) | 0.0191571  |
# +---------+------------+
# | age(58) | 0.0344828  |
# +---------+------------+
# | age(59) | 0.0229885  |
# +---------+------------+
# | age(60) | 0.00766284 |
# +---------+------------+
# | age(61) | 0.00766284 |
# +---------+------------+
# | age(62) | 0.00766284 |
# +---------+------------+
# | age(63) | 0.00383142 |
# +---------+------------+
# | age(65) | 0.0114943  |
# +---------+------------+
# | age(66) | 0          |
# +---------+------------+

# %%
print(model.get_cpds("chol"))
# Out:
# +--------------+----------------------+----------------------+
# | heartdisease | heartdisease(0)      | heartdisease(1)      |
# +--------------+----------------------+----------------------+
# | chol(100)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(117)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(129)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(132)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(147)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(156)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(160)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(161)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(163)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(164)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(166)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(167)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(168)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(171)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(172)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(173)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(175)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(179)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(180)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(182)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(184)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(186)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(187)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(188)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(190)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(193)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(194)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(195)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(196)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(198)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(200)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(201)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(202)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(204)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(205)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(206)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(207)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(208)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(209)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(210)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(211)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(212)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(213)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(214)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(215)    | 0.024539877300613498 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(216)    | 0.012269938650306749 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(217)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(218)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(219)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(220)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(221)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(222)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(223)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(224)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(225)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(226)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(227)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(228)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(229)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(230)    | 0.024539877300613498 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(231)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(233)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(234)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(237)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(238)    | 0.024539877300613498 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(240)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(241)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(242)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(243)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(245)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(246)    | 0.012269938650306749 | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(247)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(248)    | 0.0                  | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(249)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(250)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(251)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(253)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(254)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(255)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(256)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(257)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(259)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(260)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(263)    | 0.006134969325153374 | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(264)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(265)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(266)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(267)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(268)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(269)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(270)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(271)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(272)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(273)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(274)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(275)    | 0.012269938650306749 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(276)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(277)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(279)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(280)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(281)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(282)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(283)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(284)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(285)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(287)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(288)    | 0.0                  | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(289)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(290)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(291)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(292)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(294)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(295)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(297)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(298)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(303)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(305)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(306)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(307)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(308)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(309)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(312)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(315)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(318)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(320)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(326)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(328)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(329)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(331)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(336)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(338)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(339)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(340)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(341)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(342)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(344)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(347)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(355)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(358)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(365)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(388)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(392)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(393)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(394)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(404)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(412)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(466)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(468)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(491)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(518)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(529)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(603)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(85)     | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+

# %%
print(model.get_cpds("sex"))
# Out:
# +--------+----------+
# | sex(0) | 0.264368 |
# +--------+----------+
# | sex(1) | 0.735632 |
# +--------+----------+

# %%
model.get_independencies()
# Out:
# (age _|_ exang, sex)
# (age _|_ sex | exang)
# (age _|_ thalach, restecg, chol | heartdisease)
# (age _|_ exang | sex)
# (age _|_ exang, sex | fbs)
# (age _|_ thalach, restecg, chol | exang, heartdisease)
# (age _|_ sex | exang, fbs)
# (age _|_ thalach, chol | heartdisease, restecg)
# (age _|_ thalach, restecg, chol | sex, heartdisease)
# (age _|_ restecg, chol | thalach, heartdisease)
# (age _|_ thalach, restecg, chol | heartdisease, fbs)
# (age _|_ thalach, restecg | heartdisease, chol)
# (age _|_ thalach, restecg, chol | heartdisease, trestbps)
# (age _|_ exang | sex, fbs)
# (age _|_ thalach, heartdisease, chol, restecg | fbs, trestbps)
# (age _|_ thalach, chol | exang, heartdisease, restecg)
# (age _|_ thalach, restecg, chol | exang, heartdisease, sex)
# (age _|_ restecg, chol | exang, heartdisease, thalach)
# (age _|_ thalach, restecg, chol | exang, heartdisease, fbs)
# (age _|_ thalach, restecg | exang, heartdisease, chol)
# (age _|_ thalach, restecg, chol | exang, heartdisease, trestbps)
# (age _|_ thalach, heartdisease, chol, restecg | exang, fbs, trestbps)
# (age _|_ thalach, chol | sex, heartdisease, restecg)
# (age _|_ chol | thalach, heartdisease, restecg)
# (age _|_ thalach, chol | heartdisease, fbs, restecg)
# (age _|_ thalach | heartdisease, chol, restecg)
# (age _|_ thalach, chol | heartdisease, trestbps, restecg)
# (age _|_ restecg, chol | sex, heartdisease, thalach)
# (age _|_ thalach, restecg, chol | sex, heartdisease, fbs)
# (age _|_ thalach, restecg | sex, heartdisease, chol)
# (age _|_ thalach, restecg, chol | sex, heartdisease, trestbps)
# (age _|_ restecg, chol | thalach, heartdisease, fbs)
# (age _|_ restecg | thalach, heartdisease, chol)
# (age _|_ restecg, chol | thalach, heartdisease, trestbps)
# (age _|_ thalach, restecg | chol, heartdisease, fbs)
# (age _|_ thalach, restecg, chol | heartdisease, fbs, trestbps)
# (age _|_ thalach, restecg | heartdisease, chol, trestbps)
# (age _|_ thalach, heartdisease, chol | restecg, fbs, trestbps)
# (age _|_ thalach, heartdisease, chol, restecg | sex, fbs, trestbps)
# (age _|_ heartdisease, chol, restecg | thalach, fbs, trestbps)
# (age _|_ thalach, heartdisease, restecg | chol, fbs, trestbps)
# (age _|_ thalach, chol | exang, heartdisease, sex, restecg)
# (age _|_ chol | exang, heartdisease, thalach, restecg)
# (age _|_ thalach, chol | exang, heartdisease, fbs, restecg)
# (age _|_ thalach | exang, heartdisease, chol, restecg)
# (age _|_ thalach, chol | exang, heartdisease, trestbps, restecg)
# (age _|_ restecg, chol | exang, heartdisease, sex, thalach)
# (age _|_ thalach, restecg, chol | exang, heartdisease, sex, fbs)
# (age _|_ thalach, restecg | exang, heartdisease, sex, chol)
# (age _|_ thalach, restecg, chol | exang, heartdisease, sex, trestbps)
# (age _|_ restecg, chol | exang, heartdisease, fbs, thalach)
# (age _|_ restecg | exang, chol, heartdisease, thalach)
# (age _|_ restecg, chol | exang, heartdisease, thalach, trestbps)
# (age _|_ thalach, restecg | exang, chol, heartdisease, fbs)
# (age _|_ thalach, restecg, chol | exang, heartdisease, fbs, trestbps)
# (age _|_ thalach, restecg | exang, heartdisease, chol, trestbps)
# (age _|_ thalach, heartdisease, chol | exang, restecg, fbs, trestbps)
# (age _|_ thalach, heartdisease, chol, restecg | exang, sex, fbs, trestbps)
# (age _|_ heartdisease, chol, restecg | exang, fbs, thalach, trestbps)
# (age _|_ thalach, heartdisease, restecg | exang, chol, fbs, trestbps)
# (age _|_ chol | sex, heartdisease, thalach, restecg)
# (age _|_ thalach, chol | sex, heartdisease, fbs, restecg)
# (age _|_ thalach | sex, heartdisease, chol, restecg)
# (age _|_ thalach, chol | sex, heartdisease, trestbps, restecg)
# (age _|_ chol | thalach, heartdisease, fbs, restecg)
# (age _|_ chol | thalach, heartdisease, trestbps, restecg)
# (age _|_ thalach | chol, heartdisease, fbs, restecg)
# (age _|_ thalach, chol | heartdisease, fbs, restecg, trestbps)
# (age _|_ thalach | heartdisease, chol, restecg, trestbps)
# (age _|_ restecg, chol | sex, heartdisease, fbs, thalach)
# (age _|_ restecg | sex, chol, heartdisease, thalach)
# (age _|_ restecg, chol | sex, heartdisease, thalach, trestbps)
# (age _|_ thalach, restecg | sex, chol, heartdisease, fbs)
# (age _|_ thalach, restecg, chol | sex, heartdisease, fbs, trestbps)
# (age _|_ thalach, restecg | sex, heartdisease, chol, trestbps)
# (age _|_ restecg | thalach, chol, heartdisease, fbs)
# (age _|_ restecg, chol | thalach, heartdisease, fbs, trestbps)
# (age _|_ restecg | thalach, heartdisease, chol, trestbps)
# (age _|_ thalach, restecg | chol, heartdisease, fbs, trestbps)
# (age _|_ thalach, heartdisease, chol | sex, restecg, fbs, trestbps)
# (age _|_ heartdisease, chol | thalach, restecg, fbs, trestbps)
# (age _|_ thalach, heartdisease | chol, restecg, fbs, trestbps)
# (age _|_ heartdisease, chol, restecg | sex, fbs, thalach, trestbps)
# (age _|_ thalach, heartdisease, restecg | sex, chol, fbs, trestbps)
# (age _|_ heartdisease, restecg | thalach, chol, fbs, trestbps)
# (age _|_ chol | exang, heartdisease, restecg, sex, thalach)
# (age _|_ thalach, chol | exang, heartdisease, restecg, sex, fbs)
# (age _|_ thalach | exang, heartdisease, restecg, sex, chol)
# (age _|_ thalach, chol | exang, heartdisease, restecg, sex, trestbps)
# (age _|_ chol | exang, heartdisease, restecg, thalach, fbs)
# (age _|_ chol | exang, heartdisease, restecg, thalach, trestbps)
# (age _|_ thalach | exang, heartdisease, restecg, fbs, chol)
# (age _|_ thalach, chol | exang, heartdisease, restecg, fbs, trestbps)
# (age _|_ thalach | exang, heartdisease, restecg, chol, trestbps)
# (age _|_ restecg, chol | exang, heartdisease, sex, thalach, fbs)
# (age _|_ restecg | exang, heartdisease, sex, thalach, chol)
# (age _|_ restecg, chol | exang, heartdisease, sex, thalach, trestbps)
# (age _|_ thalach, restecg | exang, heartdisease, sex, fbs, chol)
# (age _|_ thalach, restecg, chol | exang, heartdisease, sex, fbs, trestbps)
# (age _|_ thalach, restecg | exang, heartdisease, sex, chol, trestbps)
# (age _|_ restecg | exang, heartdisease, thalach, fbs, chol)
# (age _|_ restecg, chol | exang, heartdisease, thalach, fbs, trestbps)
# (age _|_ restecg | exang, heartdisease, thalach, chol, trestbps)
# (age _|_ thalach, restecg | exang, heartdisease, fbs, chol, trestbps)
# (age _|_ thalach, heartdisease, chol | exang, restecg, sex, fbs, trestbps)
# (age _|_ heartdisease, chol | exang, restecg, thalach, fbs, trestbps)
# (age _|_ thalach, heartdisease | exang, restecg, fbs, chol, trestbps)
# (age _|_ heartdisease, chol, restecg | exang, sex, thalach, fbs, trestbps)
# (age _|_ thalach, heartdisease, restecg | exang, sex, fbs, chol, trestbps)
# (age _|_ heartdisease, restecg | exang, thalach, fbs, chol, trestbps)
# (age _|_ chol | heartdisease, restecg, sex, thalach, fbs)
# (age _|_ chol | heartdisease, restecg, sex, thalach, trestbps)
# (age _|_ thalach | heartdisease, restecg, sex, fbs, chol)
# (age _|_ thalach, chol | heartdisease, restecg, sex, fbs, trestbps)
# (age _|_ thalach | heartdisease, restecg, sex, chol, trestbps)
# (age _|_ chol | heartdisease, restecg, thalach, fbs, trestbps)
# (age _|_ thalach | heartdisease, restecg, fbs, chol, trestbps)
# (age _|_ restecg | heartdisease, sex, thalach, fbs, chol)
# (age _|_ restecg, chol | heartdisease, sex, thalach, fbs, trestbps)
# (age _|_ restecg | heartdisease, sex, thalach, chol, trestbps)
# (age _|_ thalach, restecg | heartdisease, sex, fbs, chol, trestbps)
# (age _|_ restecg | heartdisease, thalach, fbs, chol, trestbps)
# (age _|_ heartdisease, chol | restecg, sex, thalach, fbs, trestbps)
# (age _|_ thalach, heartdisease | restecg, sex, fbs, chol, trestbps)
# (age _|_ heartdisease | restecg, thalach, fbs, chol, trestbps)
# (age _|_ heartdisease, restecg | sex, thalach, fbs, chol, trestbps)
# (age _|_ chol | exang, heartdisease, restecg, sex, thalach, fbs)
# (age _|_ chol | exang, heartdisease, restecg, sex, thalach, trestbps)
# (age _|_ thalach | exang, heartdisease, restecg, sex, fbs, chol)
# (age _|_ thalach, chol | exang, heartdisease, restecg, sex, fbs, trestbps)
# (age _|_ thalach | exang, heartdisease, restecg, sex, chol, trestbps)
# (age _|_ chol | exang, heartdisease, restecg, thalach, fbs, trestbps)
# (age _|_ thalach | exang, heartdisease, restecg, fbs, chol, trestbps)
# (age _|_ restecg | exang, heartdisease, sex, thalach, fbs, chol)
# (age _|_ restecg, chol | exang, heartdisease, sex, thalach, fbs, trestbps)
# (age _|_ restecg | exang, heartdisease, sex, thalach, chol, trestbps)
# (age _|_ thalach, restecg | exang, heartdisease, sex, fbs, chol, trestbps)
# (age _|_ restecg | exang, heartdisease, thalach, fbs, chol, trestbps)
# (age _|_ heartdisease, chol | exang, restecg, sex, thalach, fbs, trestbps)
# (age _|_ thalach, heartdisease | exang, restecg, sex, fbs, chol, trestbps)
# (age _|_ heartdisease | exang, restecg, thalach, fbs, chol, trestbps)
# (age _|_ heartdisease, restecg | exang, sex, thalach, fbs, chol, trestbps)
# (age _|_ chol | heartdisease, restecg, sex, thalach, fbs, trestbps)
# (age _|_ thalach | heartdisease, restecg, sex, fbs, chol, trestbps)
# (age _|_ restecg | heartdisease, sex, thalach, fbs, chol, trestbps)
# (age _|_ heartdisease | restecg, sex, thalach, fbs, chol, trestbps)
# (age _|_ chol | exang, heartdisease, restecg, sex, thalach, fbs, trestbps)
# (age _|_ thalach | exang, heartdisease, restecg, sex, fbs, chol, trestbps)
# (age _|_ restecg | exang, heartdisease, sex, thalach, fbs, chol, trestbps)
# (age _|_ heartdisease | exang, restecg, sex, thalach, fbs, chol, trestbps)
# (trestbps _|_ thalach, restecg, chol | heartdisease)
# (trestbps _|_ fbs | age)
# (trestbps _|_ thalach, restecg, chol | exang, heartdisease)
# (trestbps _|_ fbs | exang, age)
# (trestbps _|_ thalach, chol | heartdisease, restecg)
# (trestbps _|_ thalach, restecg, chol | sex, heartdisease)
# (trestbps _|_ restecg, chol | thalach, heartdisease)
# (trestbps _|_ thalach, restecg, chol | heartdisease, fbs)
# (trestbps _|_ thalach, restecg | heartdisease, chol)
# (trestbps _|_ thalach, restecg, chol | age, heartdisease)
# (trestbps _|_ fbs | sex, age)
# (trestbps _|_ thalach, chol | exang, heartdisease, restecg)
# (trestbps _|_ thalach, restecg, chol | exang, heartdisease, sex)
# (trestbps _|_ restecg, chol | exang, heartdisease, thalach)
# (trestbps _|_ thalach, restecg, chol | exang, heartdisease, fbs)
# (trestbps _|_ thalach, restecg | exang, heartdisease, chol)
# (trestbps _|_ thalach, restecg, chol | exang, age, heartdisease)
# (trestbps _|_ fbs | exang, age, sex)
# (trestbps _|_ thalach, chol | sex, heartdisease, restecg)
# (trestbps _|_ chol | thalach, heartdisease, restecg)
# (trestbps _|_ thalach, chol | heartdisease, fbs, restecg)
# (trestbps _|_ thalach | heartdisease, chol, restecg)
# (trestbps _|_ thalach, chol | age, heartdisease, restecg)
# (trestbps _|_ restecg, chol | sex, heartdisease, thalach)
# (trestbps _|_ thalach, restecg, chol | sex, heartdisease, fbs)
# (trestbps _|_ thalach, restecg | sex, heartdisease, chol)
# (trestbps _|_ thalach, restecg, chol | sex, age, heartdisease)
# (trestbps _|_ restecg, chol | thalach, heartdisease, fbs)
# (trestbps _|_ restecg | thalach, heartdisease, chol)
# (trestbps _|_ restecg, chol | thalach, age, heartdisease)
# (trestbps _|_ thalach, restecg | chol, heartdisease, fbs)
# (trestbps _|_ thalach, restecg, chol | age, heartdisease, fbs)
# (trestbps _|_ thalach, restecg | age, heartdisease, chol)
# (trestbps _|_ thalach, chol | exang, heartdisease, sex, restecg)
# (trestbps _|_ chol | exang, heartdisease, thalach, restecg)
# (trestbps _|_ thalach, chol | exang, heartdisease, fbs, restecg)
# (trestbps _|_ thalach | exang, heartdisease, chol, restecg)
# (trestbps _|_ thalach, chol | exang, age, heartdisease, restecg)
# (trestbps _|_ restecg, chol | exang, heartdisease, sex, thalach)
# (trestbps _|_ thalach, restecg, chol | exang, heartdisease, sex, fbs)
# (trestbps _|_ thalach, restecg | exang, heartdisease, sex, chol)
# (trestbps _|_ thalach, restecg, chol | exang, age, heartdisease, sex)
# (trestbps _|_ restecg, chol | exang, heartdisease, fbs, thalach)
# (trestbps _|_ restecg | exang, chol, heartdisease, thalach)
# (trestbps _|_ restecg, chol | exang, age, heartdisease, thalach)
# (trestbps _|_ thalach, restecg | exang, chol, heartdisease, fbs)
# (trestbps _|_ thalach, restecg, chol | exang, age, heartdisease, fbs)
# (trestbps _|_ thalach, restecg | exang, age, heartdisease, chol)
# (trestbps _|_ chol | sex, heartdisease, thalach, restecg)
# (trestbps _|_ thalach, chol | sex, heartdisease, fbs, restecg)
# (trestbps _|_ thalach | sex, heartdisease, chol, restecg)
# (trestbps _|_ thalach, chol | sex, age, heartdisease, restecg)
# (trestbps _|_ chol | thalach, heartdisease, fbs, restecg)
# (trestbps _|_ chol | thalach, age, heartdisease, restecg)
# (trestbps _|_ thalach | chol, heartdisease, fbs, restecg)
# (trestbps _|_ thalach, chol | age, heartdisease, fbs, restecg)
# (trestbps _|_ thalach | age, heartdisease, chol, restecg)
# (trestbps _|_ restecg, chol | sex, heartdisease, fbs, thalach)
# (trestbps _|_ restecg | sex, chol, heartdisease, thalach)
# (trestbps _|_ restecg, chol | sex, age, heartdisease, thalach)
# (trestbps _|_ thalach, restecg | sex, chol, heartdisease, fbs)
# (trestbps _|_ thalach, restecg, chol | sex, age, heartdisease, fbs)
# (trestbps _|_ thalach, restecg | sex, age, heartdisease, chol)
# (trestbps _|_ restecg | thalach, chol, heartdisease, fbs)
# (trestbps _|_ restecg, chol | thalach, age, heartdisease, fbs)
# (trestbps _|_ restecg | thalach, age, heartdisease, chol)
# (trestbps _|_ thalach, restecg | chol, age, heartdisease, fbs)
# (trestbps _|_ chol | exang, heartdisease, restecg, sex, thalach)
# (trestbps _|_ thalach, chol | exang, heartdisease, restecg, sex, fbs)
# (trestbps _|_ thalach | exang, heartdisease, restecg, sex, chol)
# (trestbps _|_ thalach, chol | exang, heartdisease, restecg, sex, age)
# (trestbps _|_ chol | exang, heartdisease, restecg, thalach, fbs)
# (trestbps _|_ chol | exang, heartdisease, restecg, thalach, age)
# (trestbps _|_ thalach | exang, heartdisease, restecg, fbs, chol)
# (trestbps _|_ thalach, chol | exang, heartdisease, restecg, fbs, age)
# (trestbps _|_ thalach | exang, heartdisease, restecg, age, chol)
# (trestbps _|_ restecg, chol | exang, heartdisease, sex, thalach, fbs)
# (trestbps _|_ restecg | exang, heartdisease, sex, thalach, chol)
# (trestbps _|_ restecg, chol | exang, heartdisease, sex, thalach, age)
# (trestbps _|_ thalach, restecg | exang, heartdisease, sex, fbs, chol)
# (trestbps _|_ thalach, restecg, chol | exang, heartdisease, sex, fbs, age)
# (trestbps _|_ thalach, restecg | exang, heartdisease, sex, age, chol)
# (trestbps _|_ restecg | exang, heartdisease, thalach, fbs, chol)
# (trestbps _|_ restecg, chol | exang, heartdisease, thalach, fbs, age)
# (trestbps _|_ restecg | exang, heartdisease, thalach, age, chol)
# (trestbps _|_ thalach, restecg | exang, heartdisease, fbs, age, chol)
# (trestbps _|_ chol | heartdisease, restecg, sex, thalach, fbs)
# (trestbps _|_ chol | heartdisease, restecg, sex, thalach, age)
# (trestbps _|_ thalach | heartdisease, restecg, sex, fbs, chol)
# (trestbps _|_ thalach, chol | heartdisease, restecg, sex, fbs, age)
# (trestbps _|_ thalach | heartdisease, restecg, sex, age, chol)
# (trestbps _|_ chol | heartdisease, restecg, thalach, fbs, age)
# (trestbps _|_ thalach | heartdisease, restecg, fbs, age, chol)
# (trestbps _|_ restecg | heartdisease, sex, thalach, fbs, chol)
# (trestbps _|_ restecg, chol | heartdisease, sex, thalach, fbs, age)
# (trestbps _|_ restecg | heartdisease, sex, thalach, age, chol)
# (trestbps _|_ thalach, restecg | heartdisease, sex, fbs, age, chol)
# (trestbps _|_ restecg | heartdisease, thalach, fbs, age, chol)
# (trestbps _|_ chol | exang, heartdisease, restecg, sex, thalach, fbs)
# (trestbps _|_ chol | exang, heartdisease, restecg, sex, thalach, age)
# (trestbps _|_ thalach | exang, heartdisease, restecg, sex, fbs, chol)
# (trestbps _|_ thalach, chol | exang, heartdisease, restecg, sex, fbs, age)
# (trestbps _|_ thalach | exang, heartdisease, restecg, sex, age, chol)
# (trestbps _|_ chol | exang, heartdisease, restecg, thalach, fbs, age)
# (trestbps _|_ thalach | exang, heartdisease, restecg, fbs, age, chol)
# (trestbps _|_ restecg | exang, heartdisease, sex, thalach, fbs, chol)
# (trestbps _|_ restecg, chol | exang, heartdisease, sex, thalach, fbs, age)
# (trestbps _|_ restecg | exang, heartdisease, sex, thalach, age, chol)
# (trestbps _|_ thalach, restecg | exang, heartdisease, sex, fbs, age, chol)
# (trestbps _|_ restecg | exang, heartdisease, thalach, fbs, age, chol)
# (trestbps _|_ chol | heartdisease, restecg, sex, thalach, fbs, age)
# (trestbps _|_ thalach | heartdisease, restecg, sex, fbs, age, chol)
# (trestbps _|_ restecg | heartdisease, sex, thalach, fbs, age, chol)
# (trestbps _|_ chol | exang, heartdisease, restecg, sex, thalach, fbs, age)
# (trestbps _|_ thalach | exang, heartdisease, restecg, sex, fbs, age, chol)
# (trestbps _|_ restecg | exang, heartdisease, sex, thalach, fbs, age, chol)
# (fbs _|_ exang, sex)
# (fbs _|_ sex | exang)
# (fbs _|_ thalach, restecg, chol | heartdisease)
# (fbs _|_ exang | sex)
# (fbs _|_ exang, sex, trestbps | age)
# (fbs _|_ thalach, restecg, chol | exang, heartdisease)
# (fbs _|_ sex, trestbps | exang, age)
# (fbs _|_ thalach, chol | heartdisease, restecg)
# (fbs _|_ thalach, restecg, chol | sex, heartdisease)
# (fbs _|_ restecg, chol | thalach, heartdisease)
# (fbs _|_ thalach, restecg | heartdisease, chol)
# (fbs _|_ thalach, restecg, chol | age, heartdisease)
# (fbs _|_ thalach, restecg, chol | heartdisease, trestbps)
# (fbs _|_ exang, trestbps | sex, age)
# (fbs _|_ exang, sex | age, trestbps)
# (fbs _|_ thalach, chol | exang, heartdisease, restecg)
# (fbs _|_ thalach, restecg, chol | exang, heartdisease, sex)
# (fbs _|_ restecg, chol | exang, heartdisease, thalach)
# (fbs _|_ thalach, restecg | exang, heartdisease, chol)
# (fbs _|_ thalach, restecg, chol | exang, age, heartdisease)
# (fbs _|_ thalach, restecg, chol | exang, heartdisease, trestbps)
# (fbs _|_ trestbps | exang, age, sex)
# (fbs _|_ sex | exang, age, trestbps)
# (fbs _|_ thalach, chol | sex, heartdisease, restecg)
# (fbs _|_ chol | thalach, heartdisease, restecg)
# (fbs _|_ thalach | heartdisease, chol, restecg)
# (fbs _|_ thalach, chol | age, heartdisease, restecg)
# (fbs _|_ thalach, chol | heartdisease, trestbps, restecg)
# (fbs _|_ restecg, chol | sex, heartdisease, thalach)
# (fbs _|_ thalach, restecg | sex, heartdisease, chol)
# (fbs _|_ thalach, restecg, chol | sex, age, heartdisease)
# (fbs _|_ thalach, restecg, chol | sex, heartdisease, trestbps)
# (fbs _|_ restecg | thalach, heartdisease, chol)
# (fbs _|_ restecg, chol | thalach, age, heartdisease)
# (fbs _|_ restecg, chol | thalach, heartdisease, trestbps)
# (fbs _|_ thalach, restecg | age, heartdisease, chol)
# (fbs _|_ thalach, restecg | heartdisease, chol, trestbps)
# (fbs _|_ exang, sex, thalach, restecg, chol | age, heartdisease, trestbps)
# (fbs _|_ exang, sex | age, restecg, trestbps)
# (fbs _|_ exang | sex, age, trestbps)
# (fbs _|_ exang, sex | thalach, age, trestbps)
# (fbs _|_ exang, sex | age, chol, trestbps)
# (fbs _|_ thalach, chol | exang, heartdisease, sex, restecg)
# (fbs _|_ chol | exang, heartdisease, thalach, restecg)
# (fbs _|_ thalach | exang, heartdisease, chol, restecg)
# (fbs _|_ thalach, chol | exang, age, heartdisease, restecg)
# (fbs _|_ thalach, chol | exang, heartdisease, trestbps, restecg)
# (fbs _|_ restecg, chol | exang, heartdisease, sex, thalach)
# (fbs _|_ thalach, restecg | exang, heartdisease, sex, chol)
# (fbs _|_ thalach, restecg, chol | exang, age, heartdisease, sex)
# (fbs _|_ thalach, restecg, chol | exang, heartdisease, sex, trestbps)
# (fbs _|_ restecg | exang, chol, heartdisease, thalach)
# (fbs _|_ restecg, chol | exang, age, heartdisease, thalach)
# (fbs _|_ restecg, chol | exang, heartdisease, thalach, trestbps)
# (fbs _|_ thalach, restecg | exang, age, heartdisease, chol)
# (fbs _|_ thalach, restecg | exang, heartdisease, chol, trestbps)
# (fbs _|_ sex, thalach, restecg, chol | exang, age, heartdisease, trestbps)
# (fbs _|_ sex | exang, age, restecg, trestbps)
# (fbs _|_ sex | exang, age, thalach, trestbps)
# (fbs _|_ sex | exang, age, chol, trestbps)
# (fbs _|_ chol | sex, heartdisease, thalach, restecg)
# (fbs _|_ thalach | sex, heartdisease, chol, restecg)
# (fbs _|_ thalach, chol | sex, age, heartdisease, restecg)
# (fbs _|_ thalach, chol | sex, heartdisease, trestbps, restecg)
# (fbs _|_ chol | thalach, age, heartdisease, restecg)
# (fbs _|_ chol | thalach, heartdisease, trestbps, restecg)
# (fbs _|_ thalach | age, heartdisease, chol, restecg)
# (fbs _|_ thalach | heartdisease, chol, restecg, trestbps)
# (fbs _|_ exang, thalach, sex, chol | age, heartdisease, trestbps, restecg)
# (fbs _|_ restecg | sex, chol, heartdisease, thalach)
# (fbs _|_ restecg, chol | sex, age, heartdisease, thalach)
# (fbs _|_ restecg, chol | sex, heartdisease, thalach, trestbps)
# (fbs _|_ thalach, restecg | sex, age, heartdisease, chol)
# (fbs _|_ thalach, restecg | sex, heartdisease, chol, trestbps)
# (fbs _|_ exang, thalach, restecg, chol | sex, age, heartdisease, trestbps)
# (fbs _|_ restecg | thalach, age, heartdisease, chol)
# (fbs _|_ restecg | thalach, heartdisease, chol, trestbps)
# (fbs _|_ exang, restecg, sex, chol | thalach, age, heartdisease, trestbps)
# (fbs _|_ exang, restecg, sex, thalach | age, heartdisease, chol, trestbps)
# (fbs _|_ exang | sex, age, restecg, trestbps)
# (fbs _|_ exang, sex | thalach, age, restecg, trestbps)
# (fbs _|_ exang, sex | age, restecg, chol, trestbps)
# (fbs _|_ exang | sex, age, thalach, trestbps)
# (fbs _|_ exang | sex, age, chol, trestbps)
# (fbs _|_ exang, sex | thalach, age, chol, trestbps)
# (fbs _|_ chol | exang, heartdisease, restecg, sex, thalach)
# (fbs _|_ thalach | exang, heartdisease, restecg, sex, chol)
# (fbs _|_ thalach, chol | exang, heartdisease, restecg, sex, age)
# (fbs _|_ thalach, chol | exang, heartdisease, restecg, sex, trestbps)
# (fbs _|_ chol | exang, heartdisease, restecg, thalach, age)
# (fbs _|_ chol | exang, heartdisease, restecg, thalach, trestbps)
# (fbs _|_ thalach | exang, heartdisease, restecg, age, chol)
# (fbs _|_ thalach | exang, heartdisease, restecg, chol, trestbps)
# (fbs _|_ sex, thalach, chol | exang, heartdisease, restecg, age, trestbps)
# (fbs _|_ restecg | exang, heartdisease, sex, thalach, chol)
# (fbs _|_ restecg, chol | exang, heartdisease, sex, thalach, age)
# (fbs _|_ restecg, chol | exang, heartdisease, sex, thalach, trestbps)
# (fbs _|_ thalach, restecg | exang, heartdisease, sex, age, chol)
# (fbs _|_ thalach, restecg | exang, heartdisease, sex, chol, trestbps)
# (fbs _|_ thalach, restecg, chol | exang, heartdisease, sex, age, trestbps)
# (fbs _|_ restecg | exang, heartdisease, thalach, age, chol)
# (fbs _|_ restecg | exang, heartdisease, thalach, chol, trestbps)
# (fbs _|_ sex, restecg, chol | exang, heartdisease, thalach, age, trestbps)
# (fbs _|_ sex, restecg, thalach | exang, heartdisease, age, chol, trestbps)
# (fbs _|_ sex | exang, restecg, thalach, age, trestbps)
# (fbs _|_ sex | exang, restecg, age, chol, trestbps)
# (fbs _|_ sex | exang, thalach, chol, age, trestbps)
# (fbs _|_ chol | heartdisease, restecg, sex, thalach, age)
# (fbs _|_ chol | heartdisease, restecg, sex, thalach, trestbps)
# (fbs _|_ thalach | heartdisease, restecg, sex, age, chol)
# (fbs _|_ thalach | heartdisease, restecg, sex, chol, trestbps)
# (fbs _|_ exang, thalach, chol | heartdisease, restecg, sex, age, trestbps)
# (fbs _|_ exang, sex, chol | heartdisease, restecg, thalach, age, trestbps)
# (fbs _|_ exang, sex, thalach | heartdisease, restecg, age, chol, trestbps)
# (fbs _|_ restecg | heartdisease, sex, thalach, age, chol)
# (fbs _|_ restecg | heartdisease, sex, thalach, chol, trestbps)
# (fbs _|_ exang, restecg, chol | heartdisease, sex, thalach, age, trestbps)
# (fbs _|_ exang, restecg, thalach | heartdisease, sex, age, chol, trestbps)
# (fbs _|_ exang, restecg, sex | heartdisease, thalach, age, chol, trestbps)
# (fbs _|_ exang | restecg, sex, thalach, age, trestbps)
# (fbs _|_ exang | restecg, sex, age, chol, trestbps)
# (fbs _|_ exang, sex | restecg, thalach, age, chol, trestbps)
# (fbs _|_ exang | sex, thalach, chol, age, trestbps)
# (fbs _|_ chol | exang, heartdisease, restecg, sex, thalach, age)
# (fbs _|_ chol | exang, heartdisease, restecg, sex, thalach, trestbps)
# (fbs _|_ thalach | exang, heartdisease, restecg, sex, age, chol)
# (fbs _|_ thalach | exang, heartdisease, restecg, sex, chol, trestbps)
# (fbs _|_ thalach, chol | exang, heartdisease, restecg, sex, age, trestbps)
# (fbs _|_ sex, chol | exang, heartdisease, restecg, thalach, age, trestbps)
# (fbs _|_ sex, thalach | exang, heartdisease, restecg, age, chol, trestbps)
# (fbs _|_ restecg | exang, heartdisease, sex, thalach, age, chol)
# (fbs _|_ restecg | exang, heartdisease, sex, thalach, chol, trestbps)
# (fbs _|_ restecg, chol | exang, heartdisease, sex, thalach, age, trestbps)
# (fbs _|_ thalach, restecg | exang, heartdisease, sex, age, chol, trestbps)
# (fbs _|_ sex, restecg | exang, heartdisease, thalach, age, chol, trestbps)
# (fbs _|_ sex | exang, restecg, thalach, age, chol, trestbps)
# (fbs _|_ exang, chol | heartdisease, restecg, sex, thalach, age, trestbps)
# (fbs _|_ exang, thalach | heartdisease, restecg, sex, age, chol, trestbps)
# (fbs _|_ exang, sex | heartdisease, restecg, thalach, age, chol, trestbps)
# (fbs _|_ exang, restecg | heartdisease, sex, thalach, age, chol, trestbps)
# (fbs _|_ exang | restecg, sex, thalach, age, chol, trestbps)
# (fbs _|_ chol | exang, heartdisease, restecg, sex, thalach, age, trestbps)
# (fbs _|_ thalach | exang, heartdisease, restecg, sex, age, chol, trestbps)
# (fbs _|_ sex | exang, heartdisease, restecg, thalach, age, chol, trestbps)
# (fbs _|_ restecg | exang, heartdisease, sex, thalach, age, chol, trestbps)
# (fbs _|_ exang | heartdisease, restecg, sex, thalach, age, chol, trestbps)
# (sex _|_ exang, age, fbs)
# (sex _|_ age, fbs | exang)
# (sex _|_ thalach, restecg, chol | heartdisease)
# (sex _|_ exang, age | fbs)
# (sex _|_ exang, fbs | age)
# (sex _|_ thalach, restecg, chol | exang, heartdisease)
# (sex _|_ age | exang, fbs)
# (sex _|_ fbs | exang, age)
# (sex _|_ thalach, chol | heartdisease, restecg)
# (sex _|_ restecg, chol | thalach, heartdisease)
# (sex _|_ thalach, restecg, chol | heartdisease, fbs)
# (sex _|_ thalach, restecg | heartdisease, chol)
# (sex _|_ thalach, restecg, chol | age, heartdisease)
# (sex _|_ thalach, restecg, chol | heartdisease, trestbps)
# (sex _|_ exang | age, fbs)
# (sex _|_ thalach, heartdisease, chol, restecg | fbs, trestbps)
# (sex _|_ thalach, heartdisease, fbs, restecg, chol | age, trestbps)
# (sex _|_ thalach, chol | exang, heartdisease, restecg)
# (sex _|_ restecg, chol | exang, heartdisease, thalach)
# (sex _|_ thalach, restecg, chol | exang, heartdisease, fbs)
# (sex _|_ thalach, restecg | exang, heartdisease, chol)
# (sex _|_ thalach, restecg, chol | exang, age, heartdisease)
# (sex _|_ thalach, restecg, chol | exang, heartdisease, trestbps)
# (sex _|_ thalach, heartdisease, chol, restecg | exang, fbs, trestbps)
# (sex _|_ thalach, heartdisease, fbs, restecg, chol | exang, age, trestbps)
# (sex _|_ chol | thalach, heartdisease, restecg)
# (sex _|_ thalach, chol | heartdisease, fbs, restecg)
# (sex _|_ thalach | heartdisease, chol, restecg)
# (sex _|_ thalach, chol | age, heartdisease, restecg)
# (sex _|_ thalach, chol | heartdisease, trestbps, restecg)
# (sex _|_ restecg, chol | thalach, heartdisease, fbs)
# (sex _|_ restecg | thalach, heartdisease, chol)
# (sex _|_ restecg, chol | thalach, age, heartdisease)
# (sex _|_ restecg, chol | thalach, heartdisease, trestbps)
# (sex _|_ thalach, restecg | chol, heartdisease, fbs)
# (sex _|_ thalach, restecg, chol | age, heartdisease, fbs)
# (sex _|_ thalach, restecg, chol | heartdisease, fbs, trestbps)
# (sex _|_ thalach, restecg | age, heartdisease, chol)
# (sex _|_ thalach, restecg | heartdisease, chol, trestbps)
# (sex _|_ thalach, chol, restecg, fbs | age, heartdisease, trestbps)
# (sex _|_ thalach, heartdisease, chol | restecg, fbs, trestbps)
# (sex _|_ thalach, chol, heartdisease, fbs | age, restecg, trestbps)
# (sex _|_ heartdisease, chol, restecg | thalach, fbs, trestbps)
# (sex _|_ chol, heartdisease, fbs, restecg | thalach, age, trestbps)
# (sex _|_ thalach, heartdisease, restecg | chol, fbs, trestbps)
# (sex _|_ thalach, heartdisease, chol, restecg | age, fbs, trestbps)
# (sex _|_ thalach, heartdisease, fbs, restecg | age, chol, trestbps)
# (sex _|_ chol | exang, heartdisease, thalach, restecg)
# (sex _|_ thalach, chol | exang, heartdisease, fbs, restecg)
# (sex _|_ thalach | exang, heartdisease, chol, restecg)
# (sex _|_ thalach, chol | exang, age, heartdisease, restecg)
# (sex _|_ thalach, chol | exang, heartdisease, trestbps, restecg)
# (sex _|_ restecg, chol | exang, heartdisease, fbs, thalach)
# (sex _|_ restecg | exang, chol, heartdisease, thalach)
# (sex _|_ restecg, chol | exang, age, heartdisease, thalach)
# (sex _|_ restecg, chol | exang, heartdisease, thalach, trestbps)
# (sex _|_ thalach, restecg | exang, chol, heartdisease, fbs)
# (sex _|_ thalach, restecg, chol | exang, age, heartdisease, fbs)
# (sex _|_ thalach, restecg, chol | exang, heartdisease, fbs, trestbps)
# (sex _|_ thalach, restecg | exang, age, heartdisease, chol)
# (sex _|_ thalach, restecg | exang, heartdisease, chol, trestbps)
# (sex _|_ thalach, restecg, fbs, chol | exang, age, heartdisease, trestbps)
# (sex _|_ thalach, heartdisease, chol | exang, restecg, fbs, trestbps)
# (sex _|_ thalach, heartdisease, fbs, chol | exang, age, restecg, trestbps)
# (sex _|_ heartdisease, chol, restecg | exang, fbs, thalach, trestbps)
# (sex _|_ heartdisease, fbs, chol, restecg | exang, age, thalach, trestbps)
# (sex _|_ thalach, heartdisease, restecg | exang, chol, fbs, trestbps)
# (sex _|_ thalach, heartdisease, chol, restecg | exang, age, fbs, trestbps)
# (sex _|_ thalach, heartdisease, fbs, restecg | exang, age, chol, trestbps)
# (sex _|_ chol | thalach, heartdisease, fbs, restecg)
# (sex _|_ chol | thalach, age, heartdisease, restecg)
# (sex _|_ chol | thalach, heartdisease, trestbps, restecg)
# (sex _|_ thalach | chol, heartdisease, fbs, restecg)
# (sex _|_ thalach, chol | age, heartdisease, fbs, restecg)
# (sex _|_ thalach, chol | heartdisease, fbs, restecg, trestbps)
# (sex _|_ thalach | age, heartdisease, chol, restecg)
# (sex _|_ thalach | heartdisease, chol, restecg, trestbps)
# (sex _|_ thalach, fbs, chol | age, heartdisease, trestbps, restecg)
# (sex _|_ restecg | thalach, chol, heartdisease, fbs)
# (sex _|_ restecg, chol | thalach, age, heartdisease, fbs)
# (sex _|_ restecg, chol | thalach, heartdisease, fbs, trestbps)
# (sex _|_ restecg | thalach, age, heartdisease, chol)
# (sex _|_ restecg | thalach, heartdisease, chol, trestbps)
# (sex _|_ restecg, fbs, chol | thalach, age, heartdisease, trestbps)
# (sex _|_ thalach, restecg | chol, age, heartdisease, fbs)
# (sex _|_ thalach, restecg | chol, heartdisease, fbs, trestbps)
# (sex _|_ thalach, restecg, chol | age, heartdisease, fbs, trestbps)
# (sex _|_ thalach, restecg, fbs | age, heartdisease, chol, trestbps)
# (sex _|_ heartdisease, chol | thalach, restecg, fbs, trestbps)
# (sex _|_ heartdisease, fbs, chol | thalach, age, restecg, trestbps)
# (sex _|_ thalach, heartdisease | chol, restecg, fbs, trestbps)
# (sex _|_ thalach, heartdisease, chol | age, restecg, fbs, trestbps)
# (sex _|_ thalach, heartdisease, fbs | age, restecg, chol, trestbps)
# (sex _|_ heartdisease, restecg | thalach, chol, fbs, trestbps)
# (sex _|_ heartdisease, chol, restecg | thalach, age, fbs, trestbps)
# (sex _|_ heartdisease, fbs, restecg | thalach, age, chol, trestbps)
# (sex _|_ thalach, heartdisease, restecg | chol, age, fbs, trestbps)
# (sex _|_ chol | exang, heartdisease, restecg, thalach, fbs)
# (sex _|_ chol | exang, heartdisease, restecg, thalach, age)
# (sex _|_ chol | exang, heartdisease, restecg, thalach, trestbps)
# (sex _|_ thalach | exang, heartdisease, restecg, fbs, chol)
# (sex _|_ thalach, chol | exang, heartdisease, restecg, fbs, age)
# (sex _|_ thalach, chol | exang, heartdisease, restecg, fbs, trestbps)
# (sex _|_ thalach | exang, heartdisease, restecg, age, chol)
# (sex _|_ thalach | exang, heartdisease, restecg, chol, trestbps)
# (sex _|_ thalach, fbs, chol | exang, heartdisease, restecg, age, trestbps)
# (sex _|_ restecg | exang, heartdisease, thalach, fbs, chol)
# (sex _|_ restecg, chol | exang, heartdisease, thalach, fbs, age)
# (sex _|_ restecg, chol | exang, heartdisease, thalach, fbs, trestbps)
# (sex _|_ restecg | exang, heartdisease, thalach, age, chol)
# (sex _|_ restecg | exang, heartdisease, thalach, chol, trestbps)
# (sex _|_ restecg, fbs, chol | exang, heartdisease, thalach, age, trestbps)
# (sex _|_ thalach, restecg | exang, heartdisease, fbs, age, chol)
# (sex _|_ thalach, restecg | exang, heartdisease, fbs, chol, trestbps)
# (sex _|_ thalach, restecg, chol | exang, heartdisease, fbs, age, trestbps)
# (sex _|_ thalach, restecg, fbs | exang, heartdisease, age, chol, trestbps)
# (sex _|_ heartdisease, chol | exang, restecg, thalach, fbs, trestbps)
# (sex _|_ heartdisease, fbs, chol | exang, restecg, thalach, age, trestbps)
# (sex _|_ thalach, heartdisease | exang, restecg, fbs, chol, trestbps)
# (sex _|_ thalach, heartdisease, chol | exang, restecg, fbs, age, trestbps)
# (sex _|_ thalach, heartdisease, fbs | exang, restecg, age, chol, trestbps)
# (sex _|_ heartdisease, restecg | exang, thalach, fbs, chol, trestbps)
# (sex _|_ heartdisease, chol, restecg | exang, thalach, fbs, age, trestbps)
# (sex _|_ heartdisease, fbs, restecg | exang, thalach, chol, age, trestbps)
# (sex _|_ thalach, heartdisease, restecg | exang, fbs, chol, age, trestbps)
# (sex _|_ chol | heartdisease, restecg, thalach, fbs, age)
# (sex _|_ chol | heartdisease, restecg, thalach, fbs, trestbps)
# (sex _|_ fbs, chol | heartdisease, restecg, thalach, age, trestbps)
# (sex _|_ thalach | heartdisease, restecg, fbs, age, chol)
# (sex _|_ thalach | heartdisease, restecg, fbs, chol, trestbps)
# (sex _|_ thalach, chol | heartdisease, restecg, fbs, age, trestbps)
# (sex _|_ thalach, fbs | heartdisease, restecg, age, chol, trestbps)
# (sex _|_ restecg | heartdisease, thalach, fbs, age, chol)
# (sex _|_ restecg | heartdisease, thalach, fbs, chol, trestbps)
# (sex _|_ restecg, chol | heartdisease, thalach, fbs, age, trestbps)
# (sex _|_ restecg, fbs | heartdisease, thalach, age, chol, trestbps)
# (sex _|_ thalach, restecg | heartdisease, fbs, age, chol, trestbps)
# (sex _|_ heartdisease | restecg, thalach, fbs, chol, trestbps)
# (sex _|_ heartdisease, chol | restecg, thalach, fbs, age, trestbps)
# (sex _|_ heartdisease, fbs | restecg, thalach, age, chol, trestbps)
# (sex _|_ thalach, heartdisease | restecg, fbs, age, chol, trestbps)
# (sex _|_ heartdisease, restecg | thalach, fbs, chol, age, trestbps)
# (sex _|_ chol | exang, heartdisease, restecg, thalach, fbs, age)
# (sex _|_ chol | exang, heartdisease, restecg, thalach, fbs, trestbps)
# (sex _|_ fbs, chol | exang, heartdisease, restecg, thalach, age, trestbps)
# (sex _|_ thalach | exang, heartdisease, restecg, fbs, age, chol)
# (sex _|_ thalach | exang, heartdisease, restecg, fbs, chol, trestbps)
# (sex _|_ thalach, chol | exang, heartdisease, restecg, fbs, age, trestbps)
# (sex _|_ thalach, fbs | exang, heartdisease, restecg, age, chol, trestbps)
# (sex _|_ restecg | exang, heartdisease, thalach, fbs, age, chol)
# (sex _|_ restecg | exang, heartdisease, thalach, fbs, chol, trestbps)
# (sex _|_ restecg, chol | exang, heartdisease, thalach, fbs, age, trestbps)
# (sex _|_ restecg, fbs | exang, heartdisease, thalach, age, chol, trestbps)
# (sex _|_ thalach, restecg | exang, heartdisease, fbs, age, chol, trestbps)
# (sex _|_ heartdisease | exang, restecg, thalach, fbs, chol, trestbps)
# (sex _|_ heartdisease, chol | exang, restecg, thalach, fbs, age, trestbps)
# (sex _|_ heartdisease, fbs | exang, restecg, thalach, age, chol, trestbps)
# (sex _|_ thalach, heartdisease | exang, restecg, fbs, age, chol, trestbps)
# (sex _|_ heartdisease, restecg | exang, thalach, fbs, age, chol, trestbps)
# (sex _|_ chol | heartdisease, restecg, thalach, fbs, age, trestbps)
# (sex _|_ fbs | heartdisease, restecg, thalach, age, chol, trestbps)
# (sex _|_ thalach | heartdisease, restecg, fbs, age, chol, trestbps)
# (sex _|_ restecg | heartdisease, thalach, fbs, age, chol, trestbps)
# (sex _|_ heartdisease | restecg, thalach, fbs, age, chol, trestbps)
# (sex _|_ chol | exang, heartdisease, restecg, thalach, fbs, age, trestbps)
# (sex _|_ fbs | exang, heartdisease, restecg, thalach, age, chol, trestbps)
# (sex _|_ thalach | exang, heartdisease, restecg, fbs, age, chol, trestbps)
# (sex _|_ restecg | exang, heartdisease, thalach, fbs, age, chol, trestbps)
# (sex _|_ heartdisease | exang, restecg, thalach, fbs, age, chol, trestbps)
# (exang _|_ sex, age, fbs)
# (exang _|_ thalach, restecg, chol | heartdisease)
# (exang _|_ age, fbs | sex)
# (exang _|_ sex, age | fbs)
# (exang _|_ sex, fbs | age)
# (exang _|_ thalach, chol | heartdisease, restecg)
# (exang _|_ thalach, restecg, chol | sex, heartdisease)
# (exang _|_ restecg, chol | thalach, heartdisease)
# (exang _|_ thalach, restecg, chol | heartdisease, fbs)
# (exang _|_ thalach, restecg | heartdisease, chol)
# (exang _|_ thalach, restecg, chol | age, heartdisease)
# (exang _|_ thalach, restecg, chol | heartdisease, trestbps)
# (exang _|_ age | sex, fbs)
# (exang _|_ fbs | sex, age)
# (exang _|_ sex | age, fbs)
# (exang _|_ thalach, heartdisease, chol, restecg | fbs, trestbps)
# (exang _|_ thalach, heartdisease, fbs, restecg, chol | age, trestbps)
# (exang _|_ thalach, chol | sex, heartdisease, restecg)
# (exang _|_ chol | thalach, heartdisease, restecg)
# (exang _|_ thalach, chol | heartdisease, fbs, restecg)
# (exang _|_ thalach | heartdisease, chol, restecg)
# (exang _|_ thalach, chol | age, heartdisease, restecg)
# (exang _|_ thalach, chol | heartdisease, trestbps, restecg)
# (exang _|_ restecg, chol | sex, heartdisease, thalach)
# (exang _|_ thalach, restecg, chol | sex, heartdisease, fbs)
# (exang _|_ thalach, restecg | sex, heartdisease, chol)
# (exang _|_ thalach, restecg, chol | sex, age, heartdisease)
# (exang _|_ thalach, restecg, chol | sex, heartdisease, trestbps)
# (exang _|_ restecg, chol | thalach, heartdisease, fbs)
# (exang _|_ restecg | thalach, heartdisease, chol)
# (exang _|_ restecg, chol | thalach, age, heartdisease)
# (exang _|_ restecg, chol | thalach, heartdisease, trestbps)
# (exang _|_ thalach, restecg | chol, heartdisease, fbs)
# (exang _|_ thalach, restecg, chol | age, heartdisease, fbs)
# (exang _|_ thalach, restecg, chol | heartdisease, fbs, trestbps)
# (exang _|_ thalach, restecg | age, heartdisease, chol)
# (exang _|_ thalach, restecg | heartdisease, chol, trestbps)
# (exang _|_ thalach, chol, restecg, fbs | age, heartdisease, trestbps)
# (exang _|_ thalach, heartdisease, chol | restecg, fbs, trestbps)
# (exang _|_ thalach, chol, heartdisease, fbs | age, restecg, trestbps)
# (exang _|_ thalach, heartdisease, chol, restecg | sex, fbs, trestbps)
# (exang _|_ thalach, heartdisease, fbs, restecg, chol | sex, age, trestbps)
# (exang _|_ heartdisease, chol, restecg | thalach, fbs, trestbps)
# (exang _|_ chol, heartdisease, fbs, restecg | thalach, age, trestbps)
# (exang _|_ thalach, heartdisease, restecg | chol, fbs, trestbps)
# (exang _|_ thalach, heartdisease, chol, restecg | age, fbs, trestbps)
# (exang _|_ thalach, heartdisease, fbs, restecg | age, chol, trestbps)
# (exang _|_ chol | sex, heartdisease, thalach, restecg)
# (exang _|_ thalach, chol | sex, heartdisease, fbs, restecg)
# (exang _|_ thalach | sex, heartdisease, chol, restecg)
# (exang _|_ thalach, chol | sex, age, heartdisease, restecg)
# (exang _|_ thalach, chol | sex, heartdisease, trestbps, restecg)
# (exang _|_ chol | thalach, heartdisease, fbs, restecg)
# (exang _|_ chol | thalach, age, heartdisease, restecg)
# (exang _|_ chol | thalach, heartdisease, trestbps, restecg)
# (exang _|_ thalach | chol, heartdisease, fbs, restecg)
# (exang _|_ thalach, chol | age, heartdisease, fbs, restecg)
# (exang _|_ thalach, chol | heartdisease, fbs, restecg, trestbps)
# (exang _|_ thalach | age, heartdisease, chol, restecg)
# (exang _|_ thalach | heartdisease, chol, restecg, trestbps)
# (exang _|_ thalach, fbs, chol | age, heartdisease, trestbps, restecg)
# (exang _|_ restecg, chol | sex, heartdisease, fbs, thalach)
# (exang _|_ restecg | sex, chol, heartdisease, thalach)
# (exang _|_ restecg, chol | sex, age, heartdisease, thalach)
# (exang _|_ restecg, chol | sex, heartdisease, thalach, trestbps)
# (exang _|_ thalach, restecg | sex, chol, heartdisease, fbs)
# (exang _|_ thalach, restecg, chol | sex, age, heartdisease, fbs)
# (exang _|_ thalach, restecg, chol | sex, heartdisease, fbs, trestbps)
# (exang _|_ thalach, restecg | sex, age, heartdisease, chol)
# (exang _|_ thalach, restecg | sex, heartdisease, chol, trestbps)
# (exang _|_ thalach, restecg, fbs, chol | sex, age, heartdisease, trestbps)
# (exang _|_ restecg | thalach, chol, heartdisease, fbs)
# (exang _|_ restecg, chol | thalach, age, heartdisease, fbs)
# (exang _|_ restecg, chol | thalach, heartdisease, fbs, trestbps)
# (exang _|_ restecg | thalach, age, heartdisease, chol)
# (exang _|_ restecg | thalach, heartdisease, chol, trestbps)
# (exang _|_ restecg, fbs, chol | thalach, age, heartdisease, trestbps)
# (exang _|_ thalach, restecg | chol, age, heartdisease, fbs)
# (exang _|_ thalach, restecg | chol, heartdisease, fbs, trestbps)
# (exang _|_ thalach, restecg, chol | age, heartdisease, fbs, trestbps)
# (exang _|_ thalach, restecg, fbs | age, heartdisease, chol, trestbps)
# (exang _|_ thalach, heartdisease, chol | sex, restecg, fbs, trestbps)
# (exang _|_ thalach, heartdisease, fbs, chol | sex, age, restecg, trestbps)
# (exang _|_ heartdisease, chol | thalach, restecg, fbs, trestbps)
# (exang _|_ heartdisease, fbs, chol | thalach, age, restecg, trestbps)
# (exang _|_ thalach, heartdisease | chol, restecg, fbs, trestbps)
# (exang _|_ thalach, heartdisease, chol | age, restecg, fbs, trestbps)
# (exang _|_ thalach, heartdisease, fbs | age, restecg, chol, trestbps)
# (exang _|_ heartdisease, chol, restecg | sex, fbs, thalach, trestbps)
# (exang _|_ heartdisease, fbs, chol, restecg | sex, age, thalach, trestbps)
# (exang _|_ thalach, heartdisease, restecg | sex, chol, fbs, trestbps)
# (exang _|_ thalach, heartdisease, chol, restecg | sex, age, fbs, trestbps)
# (exang _|_ thalach, heartdisease, fbs, restecg | sex, age, chol, trestbps)
# (exang _|_ heartdisease, restecg | thalach, chol, fbs, trestbps)
# (exang _|_ heartdisease, chol, restecg | thalach, age, fbs, trestbps)
# (exang _|_ heartdisease, fbs, restecg | thalach, age, chol, trestbps)
# (exang _|_ thalach, heartdisease, restecg | chol, age, fbs, trestbps)
# (exang _|_ chol | heartdisease, restecg, sex, thalach, fbs)
# (exang _|_ chol | heartdisease, restecg, sex, thalach, age)
# (exang _|_ chol | heartdisease, restecg, sex, thalach, trestbps)
# (exang _|_ thalach | heartdisease, restecg, sex, fbs, chol)
# (exang _|_ thalach, chol | heartdisease, restecg, sex, fbs, age)
# (exang _|_ thalach, chol | heartdisease, restecg, sex, fbs, trestbps)
# (exang _|_ thalach | heartdisease, restecg, sex, age, chol)
# (exang _|_ thalach | heartdisease, restecg, sex, chol, trestbps)
# (exang _|_ thalach, fbs, chol | heartdisease, restecg, sex, age, trestbps)
# (exang _|_ chol | heartdisease, restecg, thalach, fbs, age)
# (exang _|_ chol | heartdisease, restecg, thalach, fbs, trestbps)
# (exang _|_ fbs, chol | heartdisease, restecg, thalach, age, trestbps)
# (exang _|_ thalach | heartdisease, restecg, fbs, age, chol)
# (exang _|_ thalach | heartdisease, restecg, fbs, chol, trestbps)
# (exang _|_ thalach, chol | heartdisease, restecg, fbs, age, trestbps)
# (exang _|_ thalach, fbs | heartdisease, restecg, age, chol, trestbps)
# (exang _|_ restecg | heartdisease, sex, thalach, fbs, chol)
# (exang _|_ restecg, chol | heartdisease, sex, thalach, fbs, age)
# (exang _|_ restecg, chol | heartdisease, sex, thalach, fbs, trestbps)
# (exang _|_ restecg | heartdisease, sex, thalach, age, chol)
# (exang _|_ restecg | heartdisease, sex, thalach, chol, trestbps)
# (exang _|_ restecg, fbs, chol | heartdisease, sex, thalach, age, trestbps)
# (exang _|_ thalach, restecg | heartdisease, sex, fbs, age, chol)
# (exang _|_ thalach, restecg | heartdisease, sex, fbs, chol, trestbps)
# (exang _|_ thalach, restecg, chol | heartdisease, sex, fbs, age, trestbps)
# (exang _|_ thalach, restecg, fbs | heartdisease, sex, age, chol, trestbps)
# (exang _|_ restecg | heartdisease, thalach, fbs, age, chol)
# (exang _|_ restecg | heartdisease, thalach, fbs, chol, trestbps)
# (exang _|_ restecg, chol | heartdisease, thalach, fbs, age, trestbps)
# (exang _|_ restecg, fbs | heartdisease, thalach, age, chol, trestbps)
# (exang _|_ thalach, restecg | heartdisease, fbs, age, chol, trestbps)
# (exang _|_ heartdisease, chol | restecg, sex, thalach, fbs, trestbps)
# (exang _|_ heartdisease, fbs, chol | restecg, sex, thalach, age, trestbps)
# (exang _|_ thalach, heartdisease | restecg, sex, fbs, chol, trestbps)
# (exang _|_ thalach, heartdisease, chol | restecg, sex, fbs, age, trestbps)
# (exang _|_ thalach, heartdisease, fbs | restecg, sex, age, chol, trestbps)
# (exang _|_ heartdisease | restecg, thalach, fbs, chol, trestbps)
# (exang _|_ heartdisease, chol | restecg, thalach, fbs, age, trestbps)
# (exang _|_ heartdisease, fbs | restecg, thalach, age, chol, trestbps)
# (exang _|_ thalach, heartdisease | restecg, fbs, age, chol, trestbps)
# (exang _|_ heartdisease, restecg | sex, thalach, fbs, chol, trestbps)
# (exang _|_ heartdisease, chol, restecg | sex, thalach, fbs, age, trestbps)
# (exang _|_ heartdisease, fbs, restecg | sex, thalach, chol, age, trestbps)
# (exang _|_ thalach, heartdisease, restecg | sex, fbs, chol, age, trestbps)
# (exang _|_ heartdisease, restecg | thalach, fbs, chol, age, trestbps)
# (exang _|_ chol | heartdisease, restecg, sex, thalach, fbs, age)
# (exang _|_ chol | heartdisease, restecg, sex, thalach, fbs, trestbps)
# (exang _|_ fbs, chol | heartdisease, restecg, sex, thalach, age, trestbps)
# (exang _|_ thalach | heartdisease, restecg, sex, fbs, age, chol)
# (exang _|_ thalach | heartdisease, restecg, sex, fbs, chol, trestbps)
# (exang _|_ thalach, chol | heartdisease, restecg, sex, fbs, age, trestbps)
# (exang _|_ thalach, fbs | heartdisease, restecg, sex, age, chol, trestbps)
# (exang _|_ chol | heartdisease, restecg, thalach, fbs, age, trestbps)
# (exang _|_ fbs | heartdisease, restecg, thalach, age, chol, trestbps)
# (exang _|_ thalach | heartdisease, restecg, fbs, age, chol, trestbps)
# (exang _|_ restecg | heartdisease, sex, thalach, fbs, age, chol)
# (exang _|_ restecg | heartdisease, sex, thalach, fbs, chol, trestbps)
# (exang _|_ restecg, chol | heartdisease, sex, thalach, fbs, age, trestbps)
# (exang _|_ restecg, fbs | heartdisease, sex, thalach, age, chol, trestbps)
# (exang _|_ thalach, restecg | heartdisease, sex, fbs, age, chol, trestbps)
# (exang _|_ restecg | heartdisease, thalach, fbs, age, chol, trestbps)
# (exang _|_ heartdisease | restecg, sex, thalach, fbs, chol, trestbps)
# (exang _|_ heartdisease, chol | restecg, sex, thalach, fbs, age, trestbps)
# (exang _|_ heartdisease, fbs | restecg, sex, thalach, age, chol, trestbps)
# (exang _|_ thalach, heartdisease | restecg, sex, fbs, age, chol, trestbps)
# (exang _|_ heartdisease | restecg, thalach, fbs, age, chol, trestbps)
# (exang _|_ heartdisease, restecg | sex, thalach, fbs, age, chol, trestbps)
# (exang _|_ chol | heartdisease, restecg, sex, thalach, fbs, age, trestbps)
# (exang _|_ fbs | heartdisease, restecg, sex, thalach, age, chol, trestbps)
# (exang _|_ thalach | heartdisease, restecg, sex, fbs, age, chol, trestbps)
# (exang _|_ restecg | heartdisease, sex, thalach, fbs, age, chol, trestbps)
# (exang _|_ heartdisease | restecg, sex, thalach, fbs, age, chol, trestbps)
# (heartdisease _|_ exang, age, sex | fbs, trestbps)
# (heartdisease _|_ exang, sex | age, trestbps)
# (heartdisease _|_ sex, age | exang, fbs, trestbps)
# (heartdisease _|_ sex | exang, age, trestbps)
# (heartdisease _|_ exang, age, sex | restecg, fbs, trestbps)
# (heartdisease _|_ exang, sex | age, restecg, trestbps)
# (heartdisease _|_ exang, age | sex, fbs, trestbps)
# (heartdisease _|_ exang | sex, age, trestbps)
# (heartdisease _|_ exang, age, sex | thalach, fbs, trestbps)
# (heartdisease _|_ exang, sex | thalach, age, trestbps)
# (heartdisease _|_ exang, age, sex | chol, fbs, trestbps)
# (heartdisease _|_ exang, sex | age, fbs, trestbps)
# (heartdisease _|_ exang, sex | age, chol, trestbps)
# (heartdisease _|_ sex, age | exang, restecg, fbs, trestbps)
# (heartdisease _|_ sex | exang, age, restecg, trestbps)
# (heartdisease _|_ age | exang, sex, fbs, trestbps)
# (heartdisease _|_ sex, age | exang, fbs, thalach, trestbps)
# (heartdisease _|_ sex | exang, age, thalach, trestbps)
# (heartdisease _|_ sex, age | exang, chol, fbs, trestbps)
# (heartdisease _|_ sex | exang, age, fbs, trestbps)
# (heartdisease _|_ sex | exang, age, chol, trestbps)
# (heartdisease _|_ exang, age | sex, restecg, fbs, trestbps)
# (heartdisease _|_ exang | sex, age, restecg, trestbps)
# (heartdisease _|_ exang, age, sex | thalach, restecg, fbs, trestbps)
# ...
# (thalach _|_ restecg, fbs, chol | exang, heartdisease, sex, age, trestbps)
# (thalach _|_ sex, restecg, trestbps | exang, heartdisease, fbs, age, chol)
# (thalach _|_ sex, age, restecg | exang, heartdisease, fbs, chol, trestbps)
# (thalach _|_ sex, restecg, chol | exang, heartdisease, fbs, age, trestbps)
# (thalach _|_ sex, restecg, fbs | exang, heartdisease, age, chol, trestbps)
# (thalach _|_ age | exang, restecg, sex, fbs, trestbps)
# (thalach _|_ sex, age | exang, restecg, fbs, chol, trestbps)
# (thalach _|_ sex | exang, restecg, fbs, age, trestbps)
# (thalach _|_ sex | exang, restecg, age, chol, trestbps)
# (thalach _|_ age | exang, sex, fbs, chol, trestbps)
# (thalach _|_ sex | exang, fbs, chol, age, trestbps)
# (thalach _|_ exang, age, trestbps | heartdisease, restecg, sex, fbs, chol)
# (thalach _|_ exang, chol, trestbps | heartdisease, restecg, sex, fbs, age)
# (thalach _|_ exang, age, chol | heartdisease, restecg, sex, fbs, trestbps)
# (thalach _|_ exang, fbs, trestbps | heartdisease, restecg, sex, age, chol)
# (thalach _|_ exang, age, fbs | heartdisease, restecg, sex, chol, trestbps)
# (thalach _|_ exang, fbs, chol | heartdisease, restecg, sex, age, trestbps)
# (thalach _|_ exang, sex, trestbps | heartdisease, restecg, fbs, age, chol)
# (thalach _|_ exang, age, sex | heartdisease, restecg, fbs, chol, trestbps)
# (thalach _|_ exang, sex, chol | heartdisease, restecg, fbs, age, trestbps)
# (thalach _|_ exang, sex, fbs | heartdisease, restecg, age, chol, trestbps)
# (thalach _|_ exang, restecg, trestbps | heartdisease, sex, fbs, age, chol)
# (thalach _|_ exang, age, restecg | heartdisease, sex, fbs, chol, trestbps)
# (thalach _|_ exang, restecg, chol | heartdisease, sex, fbs, age, trestbps)
# (thalach _|_ exang, restecg, fbs | heartdisease, sex, age, chol, trestbps)
# (thalach _|_ exang, restecg, sex | heartdisease, fbs, age, chol, trestbps)
# (thalach _|_ exang, age | restecg, sex, fbs, chol, trestbps)
# (thalach _|_ exang | restecg, sex, fbs, age, trestbps)
# (thalach _|_ exang | restecg, sex, age, chol, trestbps)
# (thalach _|_ exang, sex | restecg, fbs, age, chol, trestbps)
# (thalach _|_ exang | sex, fbs, chol, age, trestbps)
# (thalach _|_ age, trestbps | exang, heartdisease, restecg, sex, fbs, chol)
# (thalach _|_ chol, trestbps | exang, heartdisease, restecg, sex, fbs, age)
# (thalach _|_ age, chol | exang, heartdisease, restecg, sex, fbs, trestbps)
# (thalach _|_ fbs, trestbps | exang, heartdisease, restecg, sex, age, chol)
# (thalach _|_ age, fbs | exang, heartdisease, restecg, sex, chol, trestbps)
# (thalach _|_ fbs, chol | exang, heartdisease, restecg, sex, age, trestbps)
# (thalach _|_ sex, trestbps | exang, heartdisease, restecg, fbs, age, chol)
# (thalach _|_ sex, age | exang, heartdisease, restecg, fbs, chol, trestbps)
# (thalach _|_ sex, chol | exang, heartdisease, restecg, fbs, age, trestbps)
# (thalach _|_ sex, fbs | exang, heartdisease, restecg, age, chol, trestbps)
# (thalach _|_ restecg, trestbps | exang, heartdisease, sex, fbs, age, chol)
# (thalach _|_ age, restecg | exang, heartdisease, sex, fbs, chol, trestbps)
# (thalach _|_ restecg, chol | exang, heartdisease, sex, fbs, age, trestbps)
# (thalach _|_ restecg, fbs | exang, heartdisease, sex, age, chol, trestbps)
# (thalach _|_ sex, restecg | exang, heartdisease, fbs, age, chol, trestbps)
# (thalach _|_ age | exang, restecg, sex, fbs, chol, trestbps)
# (thalach _|_ sex | exang, restecg, fbs, age, chol, trestbps)
# (thalach _|_ exang, trestbps | heartdisease, restecg, sex, fbs, age, chol)
# (thalach _|_ exang, age | heartdisease, restecg, sex, fbs, chol, trestbps)
# (thalach _|_ exang, chol | heartdisease, restecg, sex, fbs, age, trestbps)
# (thalach _|_ exang, fbs | heartdisease, restecg, sex, age, chol, trestbps)
# (thalach _|_ exang, sex | heartdisease, restecg, fbs, age, chol, trestbps)
# (thalach _|_ exang, restecg | heartdisease, sex, fbs, age, chol, trestbps)
# (thalach _|_ exang | restecg, sex, fbs, age, chol, trestbps)
# (thalach _|_ trestbps | exang, heartdisease, restecg, sex, fbs, age, chol)
# (thalach _|_ age | exang, heartdisease, restecg, sex, fbs, chol, trestbps)
# (thalach _|_ chol | exang, heartdisease, restecg, sex, fbs, age, trestbps)
# (thalach _|_ fbs | exang, heartdisease, restecg, sex, age, chol, trestbps)
# (thalach _|_ sex | exang, heartdisease, restecg, fbs, age, chol, trestbps)
# (thalach _|_ restecg | exang, heartdisease, sex, fbs, age, chol, trestbps)
# (thalach _|_ exang | heartdisease, restecg, sex, fbs, age, chol, trestbps)
# (chol _|_ exang, sex, thalach, fbs, age, restecg, trestbps | heartdisease)
# (chol _|_ sex, thalach, fbs, age, restecg, trestbps | exang, heartdisease)
# (chol _|_ exang, sex, thalach, fbs, age, trestbps | heartdisease, restecg)
# (chol _|_ exang, thalach, fbs, age, restecg, trestbps | sex, heartdisease)
# (chol _|_ exang, sex, fbs, age, restecg, trestbps | thalach, heartdisease)
# (chol _|_ exang, sex, thalach, age, restecg, trestbps | heartdisease, fbs)
# (chol _|_ exang, sex, thalach, fbs, restecg, trestbps | age, heartdisease)
# (chol _|_ exang, sex, thalach, fbs, age, restecg | heartdisease, trestbps)
# (chol _|_ exang, age, sex | fbs, trestbps)
# (chol _|_ exang, sex | age, trestbps)
# (chol _|_ sex, thalach, fbs, age, trestbps | exang, heartdisease, restecg)
# (chol _|_ thalach, fbs, age, restecg, trestbps | exang, heartdisease, sex)
# (chol _|_ sex, fbs, age, restecg, trestbps | exang, heartdisease, thalach)
# (chol _|_ sex, thalach, age, restecg, trestbps | exang, heartdisease, fbs)
# (chol _|_ sex, thalach, fbs, restecg, trestbps | exang, age, heartdisease)
# (chol _|_ sex, thalach, fbs, age, restecg | exang, heartdisease, trestbps)
# (chol _|_ sex, age | exang, fbs, trestbps)
# (chol _|_ sex | exang, age, trestbps)
# (chol _|_ exang, thalach, fbs, age, trestbps | sex, heartdisease, restecg)
# (chol _|_ exang, sex, fbs, age, trestbps | thalach, heartdisease, restecg)
# (chol _|_ exang, sex, thalach, age, trestbps | heartdisease, fbs, restecg)
# (chol _|_ exang, sex, thalach, fbs, trestbps | age, heartdisease, restecg)
# (chol _|_ exang, sex, thalach, fbs, age | heartdisease, trestbps, restecg)
# (chol _|_ exang, fbs, age, restecg, trestbps | sex, heartdisease, thalach)
# (chol _|_ exang, thalach, age, restecg, trestbps | sex, heartdisease, fbs)
# (chol _|_ exang, thalach, fbs, restecg, trestbps | sex, age, heartdisease)
# (chol _|_ exang, thalach, fbs, age, restecg | sex, heartdisease, trestbps)
# (chol _|_ exang, sex, age, restecg, trestbps | thalach, heartdisease, fbs)
# (chol _|_ exang, sex, fbs, restecg, trestbps | thalach, age, heartdisease)
# (chol _|_ exang, sex, fbs, age, restecg | thalach, heartdisease, trestbps)
# (chol _|_ exang, sex, thalach, restecg, trestbps | age, heartdisease, fbs)
# (chol _|_ exang, sex, thalach, age, restecg | heartdisease, fbs, trestbps)
# (chol _|_ exang, sex, thalach, fbs, restecg | age, heartdisease, trestbps)
# (chol _|_ exang, age, sex | restecg, fbs, trestbps)
# (chol _|_ exang, sex | age, restecg, trestbps)
# (chol _|_ exang, age | sex, fbs, trestbps)
# (chol _|_ exang | sex, age, trestbps)
# (chol _|_ exang, age, sex | thalach, fbs, trestbps)
# (chol _|_ exang, sex | thalach, age, trestbps)
# (chol _|_ exang, sex | age, fbs, trestbps)
# (chol _|_ thalach, age, fbs, trestbps | exang, heartdisease, sex, restecg)
# (chol _|_ sex, age, fbs, trestbps | exang, heartdisease, thalach, restecg)
# (chol _|_ sex, age, thalach, trestbps | exang, heartdisease, fbs, restecg)
# (chol _|_ sex, thalach, fbs, trestbps | exang, age, heartdisease, restecg)
# (chol _|_ sex, age, thalach, fbs | exang, heartdisease, trestbps, restecg)
# (chol _|_ age, restecg, fbs, trestbps | exang, heartdisease, sex, thalach)
# (chol _|_ thalach, age, restecg, trestbps | exang, heartdisease, sex, fbs)
# (chol _|_ thalach, restecg, fbs, trestbps | exang, age, heartdisease, sex)
# (chol _|_ thalach, age, restecg, fbs | exang, heartdisease, sex, trestbps)
# (chol _|_ sex, age, restecg, trestbps | exang, heartdisease, fbs, thalach)
# (chol _|_ sex, restecg, fbs, trestbps | exang, age, heartdisease, thalach)
# (chol _|_ sex, age, restecg, fbs | exang, heartdisease, thalach, trestbps)
# (chol _|_ sex, restecg, thalach, trestbps | exang, age, heartdisease, fbs)
# (chol _|_ sex, age, restecg, thalach | exang, heartdisease, fbs, trestbps)
# (chol _|_ sex, thalach, restecg, fbs | exang, age, heartdisease, trestbps)
# (chol _|_ sex, age | exang, restecg, fbs, trestbps)
# (chol _|_ sex | exang, age, restecg, trestbps)
# (chol _|_ age | exang, sex, fbs, trestbps)
# (chol _|_ sex, age | exang, fbs, thalach, trestbps)
# (chol _|_ sex | exang, age, thalach, trestbps)
# (chol _|_ sex | exang, age, fbs, trestbps)
# (chol _|_ exang, age, fbs, trestbps | sex, heartdisease, thalach, restecg)
# (chol _|_ exang, age, thalach, trestbps | sex, heartdisease, fbs, restecg)
# (chol _|_ exang, thalach, fbs, trestbps | sex, age, heartdisease, restecg)
# (chol _|_ exang, age, thalach, fbs | sex, heartdisease, trestbps, restecg)
# (chol _|_ exang, age, sex, trestbps | thalach, heartdisease, fbs, restecg)
# (chol _|_ exang, sex, fbs, trestbps | thalach, age, heartdisease, restecg)
# (chol _|_ exang, age, sex, fbs | thalach, heartdisease, trestbps, restecg)
# (chol _|_ exang, sex, thalach, trestbps | age, heartdisease, fbs, restecg)
# (chol _|_ exang, age, sex, thalach | heartdisease, fbs, restecg, trestbps)
# (chol _|_ exang, thalach, sex, fbs | age, heartdisease, trestbps, restecg)
# (chol _|_ exang, age, restecg, trestbps | sex, heartdisease, fbs, thalach)
# (chol _|_ exang, restecg, fbs, trestbps | sex, age, heartdisease, thalach)
# (chol _|_ exang, age, restecg, fbs | sex, heartdisease, thalach, trestbps)
# (chol _|_ exang, restecg, thalach, trestbps | sex, age, heartdisease, fbs)
# (chol _|_ exang, age, restecg, thalach | sex, heartdisease, fbs, trestbps)
# (chol _|_ exang, thalach, restecg, fbs | sex, age, heartdisease, trestbps)
# (chol _|_ exang, restecg, sex, trestbps | thalach, age, heartdisease, fbs)
# (chol _|_ exang, age, restecg, sex | thalach, heartdisease, fbs, trestbps)
# (chol _|_ exang, restecg, sex, fbs | thalach, age, heartdisease, trestbps)
# (chol _|_ exang, restecg, sex, thalach | age, heartdisease, fbs, trestbps)
# (chol _|_ exang, age | sex, restecg, fbs, trestbps)
# (chol _|_ exang | sex, age, restecg, trestbps)
# (chol _|_ exang, age, sex | thalach, restecg, fbs, trestbps)
# (chol _|_ exang, sex | thalach, age, restecg, trestbps)
# (chol _|_ exang, sex | age, restecg, fbs, trestbps)
# (chol _|_ exang, age | sex, fbs, thalach, trestbps)
# (chol _|_ exang | sex, age, thalach, trestbps)
# (chol _|_ exang | sex, age, fbs, trestbps)
# (chol _|_ exang, sex | thalach, age, fbs, trestbps)
# (chol _|_ age, fbs, trestbps | exang, heartdisease, restecg, sex, thalach)
# (chol _|_ thalach, age, trestbps | exang, heartdisease, restecg, sex, fbs)
# (chol _|_ thalach, fbs, trestbps | exang, heartdisease, restecg, sex, age)
# (chol _|_ thalach, age, fbs | exang, heartdisease, restecg, sex, trestbps)
# (chol _|_ sex, age, trestbps | exang, heartdisease, restecg, thalach, fbs)
# (chol _|_ sex, fbs, trestbps | exang, heartdisease, restecg, thalach, age)
# (chol _|_ sex, age, fbs | exang, heartdisease, restecg, thalach, trestbps)
# (chol _|_ sex, thalach, trestbps | exang, heartdisease, restecg, fbs, age)
# (chol _|_ sex, age, thalach | exang, heartdisease, restecg, fbs, trestbps)
# (chol _|_ sex, thalach, fbs | exang, heartdisease, restecg, age, trestbps)
# (chol _|_ age, restecg, trestbps | exang, heartdisease, sex, thalach, fbs)
# (chol _|_ restecg, fbs, trestbps | exang, heartdisease, sex, thalach, age)
# (chol _|_ age, restecg, fbs | exang, heartdisease, sex, thalach, trestbps)
# (chol _|_ thalach, restecg, trestbps | exang, heartdisease, sex, fbs, age)
# (chol _|_ thalach, age, restecg | exang, heartdisease, sex, fbs, trestbps)
# (chol _|_ thalach, restecg, fbs | exang, heartdisease, sex, age, trestbps)
# (chol _|_ sex, restecg, trestbps | exang, heartdisease, thalach, fbs, age)
# (chol _|_ sex, age, restecg | exang, heartdisease, thalach, fbs, trestbps)
# (chol _|_ sex, restecg, fbs | exang, heartdisease, thalach, age, trestbps)
# (chol _|_ sex, restecg, thalach | exang, heartdisease, fbs, age, trestbps)
# (chol _|_ age | exang, restecg, sex, fbs, trestbps)
# (chol _|_ sex, age | exang, restecg, thalach, fbs, trestbps)
# (chol _|_ sex | exang, restecg, thalach, age, trestbps)
# (chol _|_ sex | exang, restecg, fbs, age, trestbps)
# (chol _|_ age | exang, sex, thalach, fbs, trestbps)
# (chol _|_ sex | exang, thalach, fbs, age, trestbps)
# (chol _|_ exang, age, trestbps | heartdisease, restecg, sex, thalach, fbs)
# (chol _|_ exang, fbs, trestbps | heartdisease, restecg, sex, thalach, age)
# (chol _|_ exang, age, fbs | heartdisease, restecg, sex, thalach, trestbps)
# (chol _|_ exang, thalach, trestbps | heartdisease, restecg, sex, fbs, age)
# (chol _|_ exang, age, thalach | heartdisease, restecg, sex, fbs, trestbps)
# (chol _|_ exang, thalach, fbs | heartdisease, restecg, sex, age, trestbps)
# (chol _|_ exang, sex, trestbps | heartdisease, restecg, thalach, fbs, age)
# (chol _|_ exang, age, sex | heartdisease, restecg, thalach, fbs, trestbps)
# (chol _|_ exang, sex, fbs | heartdisease, restecg, thalach, age, trestbps)
# (chol _|_ exang, sex, thalach | heartdisease, restecg, fbs, age, trestbps)
# (chol _|_ exang, restecg, trestbps | heartdisease, sex, thalach, fbs, age)
# (chol _|_ exang, age, restecg | heartdisease, sex, thalach, fbs, trestbps)
# (chol _|_ exang, restecg, fbs | heartdisease, sex, thalach, age, trestbps)
# (chol _|_ exang, restecg, thalach | heartdisease, sex, fbs, age, trestbps)
# (chol _|_ exang, restecg, sex | heartdisease, thalach, fbs, age, trestbps)
# (chol _|_ exang, age | restecg, sex, thalach, fbs, trestbps)
# (chol _|_ exang | restecg, sex, thalach, age, trestbps)
# (chol _|_ exang | restecg, sex, fbs, age, trestbps)
# (chol _|_ exang, sex | restecg, thalach, fbs, age, trestbps)
# (chol _|_ exang | sex, thalach, fbs, age, trestbps)
# (chol _|_ age, trestbps | exang, heartdisease, restecg, sex, thalach, fbs)
# (chol _|_ fbs, trestbps | exang, heartdisease, restecg, sex, thalach, age)
# (chol _|_ age, fbs | exang, heartdisease, restecg, sex, thalach, trestbps)
# (chol _|_ thalach, trestbps | exang, heartdisease, restecg, sex, fbs, age)
# (chol _|_ thalach, age | exang, heartdisease, restecg, sex, fbs, trestbps)
# (chol _|_ thalach, fbs | exang, heartdisease, restecg, sex, age, trestbps)
# (chol _|_ sex, trestbps | exang, heartdisease, restecg, thalach, fbs, age)
# (chol _|_ sex, age | exang, heartdisease, restecg, thalach, fbs, trestbps)
# (chol _|_ sex, fbs | exang, heartdisease, restecg, thalach, age, trestbps)
# (chol _|_ sex, thalach | exang, heartdisease, restecg, fbs, age, trestbps)
# (chol _|_ restecg, trestbps | exang, heartdisease, sex, thalach, fbs, age)
# (chol _|_ age, restecg | exang, heartdisease, sex, thalach, fbs, trestbps)
# (chol _|_ restecg, fbs | exang, heartdisease, sex, thalach, age, trestbps)
# (chol _|_ thalach, restecg | exang, heartdisease, sex, fbs, age, trestbps)
# (chol _|_ sex, restecg | exang, heartdisease, thalach, fbs, age, trestbps)
# (chol _|_ age | exang, restecg, sex, thalach, fbs, trestbps)
# (chol _|_ sex | exang, restecg, thalach, fbs, age, trestbps)
# (chol _|_ exang, trestbps | heartdisease, restecg, sex, thalach, fbs, age)
# (chol _|_ exang, age | heartdisease, restecg, sex, thalach, fbs, trestbps)
# (chol _|_ exang, fbs | heartdisease, restecg, sex, thalach, age, trestbps)
# (chol _|_ exang, thalach | heartdisease, restecg, sex, fbs, age, trestbps)
# (chol _|_ exang, sex | heartdisease, restecg, thalach, fbs, age, trestbps)
# (chol _|_ exang, restecg | heartdisease, sex, thalach, fbs, age, trestbps)
# (chol _|_ exang | restecg, sex, thalach, fbs, age, trestbps)
# (chol _|_ trestbps | exang, heartdisease, restecg, sex, thalach, fbs, age)
# (chol _|_ age | exang, heartdisease, restecg, sex, thalach, fbs, trestbps)
# (chol _|_ fbs | exang, heartdisease, restecg, sex, thalach, age, trestbps)
# (chol _|_ thalach | exang, heartdisease, restecg, sex, fbs, age, trestbps)
# (chol _|_ sex | exang, heartdisease, restecg, thalach, fbs, age, trestbps)
# (chol _|_ restecg | exang, heartdisease, sex, thalach, fbs, age, trestbps)
# (chol _|_ exang | heartdisease, restecg, sex, thalach, fbs, age, trestbps)

# %%
from pgmpy.inference import VariableElimination
heartDisease_infer = VariableElimination(model)
q = heartDisease_infer.query(variables=["heartdisease"],
evidence={"age": 29})

print(q)
# Out:
# Finding Elimination Order: : 100%|█████████████████████████████████████████████████████| 7/7 [00:00<00:00, 6995.50it/s]
# Eliminating: trestbps: 100%|████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 874.78it/s]
# +-----------------+---------------------+
# | heartdisease    |   phi(heartdisease) |
# +=================+=====================+
# | heartdisease(0) |              0.6630 |
# +-----------------+---------------------+
# | heartdisease(1) |              0.3370 |
# +-----------------+---------------------+

# %%
q = heartDisease_infer.query(variables=["heartdisease"],
evidence={"chol": 100})

print(q)
# Out:
# G:\Anaconda3\lib\site-packages\pgmpy\factors\discrete\DiscreteFactor.py:518: UserWarning: Found unknown state name. Trying to switch to using all state names as state numbers
#   warn(
# Finding Elimination Order: : 100%|█████████████████████████████████████████████████████| 7/7 [00:00<00:00, 3514.50it/s]
# Eliminating: trestbps: 100%|████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 538.33it/s]
# +-----------------+---------------------+
# | heartdisease    |   phi(heartdisease) |
# +=================+=====================+
# | heartdisease(0) |              1.0000 |
# +-----------------+---------------------+
# | heartdisease(1) |              0.0000 |
# +-----------------+---------------------+
